# %% [markdown]
# #### High-Frequency RF Characteristics ($f_T$ and $f_{max}$)
#
# This evaluates the device's AC small-signal performance:
#    * $f_T$ (Current Gain Limit): Depends on how fast electrons travel through the device. The main bottleneck is the intrinsic transit delay ($C_{gg}/g_m$).
#    * $f_{max}$ (Power Gain Limit): Depends on a high $f_T$, but it also requires low parasitic resistances and capacitances.
#
# #### Understanding the Curves
#    * Off-State ($V_{GS} < -2.5\text{ V}$): The channel is pinched off. With zero transconductance ($g_m$), RF performance is zero.
#    * The Peak (Moderate Bias): $g_m$ hits its maximum here. This gives the best $g_m / C_{gg}$ ratio, minimizing transit delay and peaking both frequencies.
#    * High-Bias Roll-Off: Performance drops at higher gate biases. Self-heating and interface scattering reduce $g_m$, while gate capacitance ($C_{gg}$) increases. This significantly increases transit time while the rise in output conductance ($g_{ds}$) from short-channel effects leading to internal power leak causes $f_{max}$ to further decrease.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.sparse as sparse
import scipy.sparse.linalg as spla
import scipy.linalg as la
import scipy.constants as const


# 1. PHYSICAL PARAMETERS & MATERIAL PROPERTIES
q = const.e
hbar = const.hbar
eps0 = const.epsilon_0
kB = const.k
T_amb = 300.0        # Ambient temperature (K)
m0 = const.m_e

# HEMT Operating Conditions
x_al = 0.22          # 22% Al Content
V_schottky = 1.2     # Schottky barrier height (V)
V_surface_pin = -1.2 # Fermi pinning level in access regions (V)
Vg = 2               # Initial Gate Voltage (V)
Vds = 2.0            # Static Drain Bias (V)

# Transport Physics Parameters
mu_0 = 0.12          # Calibrated 2DEG low-field mobility at 300K (m^2/Vs)
v_sat_300K = 1.1e5   # Effective saturation velocity in GaN at 300K (m/s)
beta_CT = 2.0        # Caughey-Thomas empirical beta

# Thermal Parameters
kappa_GaN = 130.0    # Thermal conductivity of GaN (W/m-K)
kappa_AlGaN = 20.0   # Thermal conductivity of AlGaN (W/m-K)
gamma_mu = 2.0       # Temperature exponent for mobility degradation
gamma_vsat = 1.5     # Temperature exponent for vsat degradation

# Deep Buffer Trap Parameters
E_dA = 2.5 * q       
g_A = 4.0            

# Material parameters
m_GaN = 0.20 * m0
m_AlGaN = (0.32 * x_al + 0.20 * (1.0 - x_al)) * m0
eps_GaN = 8.9 * eps0
eps_AlGaN = (8.5 * x_al + 8.9 * (1.0 - x_al)) * eps0
dE_c = 0.7 * (3.07 * x_al + 0.7 * x_al * (1.0 - x_al)) * q  

# Spontaneous & Piezoelectric Polarization Calculation
P_SP_GaN = -0.034
P_SP_AlGaN = -0.090 * x_al - 0.034 * (1.0 - x_al) + 0.021 * x_al * (1.0 - x_al)
a_GaN, a_AlN = 0.3189e-9, 0.3112e-9
a_AlGaN = a_AlN * x_al + a_GaN * (1.0 - x_al)
strain_inplane = (a_GaN - a_AlGaN) / a_AlGaN
e31 = -0.11 * x_al - 0.49 * (1.0 - x_al)
e33 = 0.73 * x_al + 0.97 * (1.0 - x_al)
C13 = (103 * x_al + 106 * (1.0 - x_al)) * 1e9
C33 = (405 * x_al + 398 * (1.0 - x_al)) * 1e9
P_PE_AlGaN = 2 * strain_inplane * (e31 - e33 * (C13 / C33))
sigma_pol = (P_SP_GaN - (P_SP_AlGaN + P_PE_AlGaN)) / q  


# 2. DEVICE TOPOLOGY & MESH GENERATION
L_s, L_sg, L_g, L_gd, L_d = 15e-9, 20e-9, 30e-9, 20e-9, 15e-9
Lx = L_s + L_sg + L_g + L_gd + L_d
t_barrier, t_buffer = 12.0e-9, 288.0e-9 
Lz = t_barrier + t_buffer

z_top = np.linspace(0, 9e-9, 15, endpoint=False)
z_2deg = np.linspace(9e-9, 18e-9, 65, endpoint=False) 
z_buf = np.geomspace(18e-9, Lz, 40)
z = np.unique(np.sort(np.concatenate([z_top, z_2deg, z_buf])))
Nz = len(z)

x_gate1 = L_s + L_sg
x_gate2 = x_gate1 + L_g
x_s = np.linspace(0, L_s, 10, endpoint=False)
x_sg = np.linspace(L_s, x_gate1, 15, endpoint=False)
x_g = np.linspace(x_gate1, x_gate2, 25, endpoint=False)
x_gd = np.linspace(x_gate2, Lx - L_d, 15, endpoint=False)
x_d = np.linspace(Lx - L_d, Lx, 15)
x = np.unique(np.sort(np.concatenate([x_s, x_sg, x_g, x_gd, x_d])))
Nx = len(x)

X, Z = np.meshgrid(x, z)
idx_int = np.argmin(np.abs(z - t_barrier))

dx_R = np.diff(x); dx_L = np.roll(dx_R, 1)                  
dx_avg = 0.5 * (np.append(dx_R, dx_R[-1]) + np.insert(dx_L, 0, dx_L[0]))
dz_R = np.diff(z); dz_L = np.roll(dz_R, 1)                  
dz_avg = 0.5 * (np.append(dz_R, dz_R[-1]) + np.insert(dz_L, 0, dz_L[0]))

m_eff = np.where(Z <= t_barrier, m_AlGaN, m_GaN)
eps_r = np.where(Z <= t_barrier, eps_AlGaN, eps_GaN)
kappa_grid = np.where(Z <= t_barrier, kappa_AlGaN, kappa_GaN)
V_band = np.where(Z <= t_barrier, dE_c, 0.0)

source_mask = (X <= L_s) & (Z == 0)
gate_mask = (X >= x_gate1) & (X <= x_gate2) & (Z == 0)
drain_mask = (X >= Lx - L_d) & (Z == 0)


# 3. DOPING
rho_fixed = np.zeros((Nz, Nx))
rho_fixed[idx_int+1:, :] += q * 1e22 
rho_fixed[idx_int, :] += (q * sigma_pol) / dz_avg[idx_int]

N_D_contacts = 2e25 
contact_depth = t_barrier + 2e-9
rho_fixed[(X <= L_s) & (Z <= contact_depth)] += q * N_D_contacts
rho_fixed[(X >= Lx - L_d) & (Z <= contact_depth)] += q * N_D_contacts

t_buffer_doped_start = t_barrier + 20e-9
idx_buffer_doped = np.max(np.where(z <= t_buffer_doped_start)[0])
N_acceptor = 5e22 

buf_trap_mask = np.zeros((Nz, Nx), dtype=bool)
buf_trap_mask[idx_buffer_doped:, :] = True

N_C_GaN = 2.0 * ((m_GaN * kB * T_amb) / (2.0 * np.pi * hbar**2))**1.5 
n_ratio = N_D_contacts / N_C_GaN
V_bi = (kB * T_amb / q) * (np.log(n_ratio) + n_ratio / np.sqrt(8))


# 4. 2D MATRICES (POISSON & THERMAL)
N_tot = Nx * Nz
A_poisson_base = sparse.lil_matrix((N_tot, N_tot))
A_therm_base = sparse.lil_matrix((N_tot, N_tot))

def get_k(i, j): return j * Nx + i

for j in range(Nz):
    for i in range(Nx):
        k = get_k(i, j)
        
        # Poisson Stencil Setup
        if gate_mask[j, i] or source_mask[j, i] or drain_mask[j, i] or j == 0:
            A_poisson_base[k, k] = 1.0
        elif j == Nz - 1: 
            A_poisson_base[k, k] = 1.0; A_poisson_base[k, get_k(i, j-1)] = -1.0
        elif i == 0:      
            A_poisson_base[k, k] = 1.0; A_poisson_base[k, get_k(i+1, j)] = -1.0
        elif i == Nx - 1: 
            A_poisson_base[k, k] = 1.0; A_poisson_base[k, get_k(i-1, j)] = -1.0
        else:
            dx_r_i, dx_l_i, dx_a_i = dx_R[i], dx_R[i-1], dx_avg[i]
            dz_r_j, dz_l_j, dz_a_j = dz_R[j], dz_R[j-1], dz_avg[j]
            
            exP = 0.5 * (eps_r[j, i] + eps_r[j, i+1]); exM = 0.5 * (eps_r[j, i] + eps_r[j, i-1])
            ezP = 0.5 * (eps_r[j, i] + eps_r[j+1, i]); ezM = 0.5 * (eps_r[j, i] + eps_r[j-1, i])
            c_iP, c_iM = exP / (dx_a_i * dx_r_i), exM / (dx_a_i * dx_l_i)
            c_jP, c_jM = ezP / (dz_a_j * dz_r_j), ezM / (dz_a_j * dz_l_j)
            A_poisson_base[k, get_k(i+1, j)] = c_iP; A_poisson_base[k, get_k(i-1, j)] = c_iM
            A_poisson_base[k, get_k(i, j+1)] = c_jP; A_poisson_base[k, get_k(i, j-1)] = c_jM
            A_poisson_base[k, k] = -(c_iP + c_iM + c_jP + c_jM)

        # Thermal Stencil Setup
        if j == Nz - 1:   
            A_therm_base[k, k] = 1.0
        elif i == 0:      
            A_therm_base[k, k] = 1.0; A_therm_base[k, get_k(i+1, j)] = -1.0
        elif i == Nx - 1: 
            A_therm_base[k, k] = 1.0; A_therm_base[k, get_k(i-1, j)] = -1.0
        elif j == 0:      
            A_therm_base[k, k] = 1.0; A_therm_base[k, get_k(i, j+1)] = -1.0
        else:
            dx_r_i, dx_l_i, dx_a_i = dx_R[i], dx_R[i-1], dx_avg[i]
            dz_r_j, dz_l_j, dz_a_j = dz_R[j], dz_R[j-1], dz_avg[j]
            
            kxP = 0.5 * (kappa_grid[j, i] + kappa_grid[j, i+1]); kxM = 0.5 * (kappa_grid[j, i] + kappa_grid[j, i-1])
            kzP = 0.5 * (kappa_grid[j, i] + kappa_grid[j+1, i]); kzM = 0.5 * (kappa_grid[j, i] + kappa_grid[j-1, i])
            tc_iP, tc_iM = kxP / (dx_a_i * dx_r_i), kxM / (dx_a_i * dx_l_i)
            tc_jP, tc_jM = kzP / (dz_a_j * dz_r_j), kzM / (dz_a_j * dz_l_j)
            A_therm_base[k, get_k(i+1, j)] = tc_iP; A_therm_base[k, get_k(i-1, j)] = tc_iM
            A_therm_base[k, get_k(i, j+1)] = tc_jP; A_therm_base[k, get_k(i, j-1)] = tc_jM
            A_therm_base[k, k] = -(tc_iP + tc_iM + tc_jP + tc_jM)

A_csr = A_poisson_base.tocsr()
A_therm_csr = A_therm_base.tocsr()


# 5. ELECTRO-THERMAL GUMMEL LOOP (GATE VOLTAGE SWEEP)
max_iter_limit = 3000
min_iters = 250
n_subbands = 3

window_size = 5
convergence_tol = 1e-4    # mA/mm tolerance
max_diverge_steps = 3   
trend_window_size = max_diverge_steps * 2  

alpha_p, alpha_n, alpha_EF, alpha_T = 0.05, 0.025, 0.025, 0.02

Vg_sweep = np.arange(Vg, -5.0, -0.5)

extracted_Vg = []
extracted_Id = []
extracted_Qg = []

gate_x_mask = (x >= x_gate1) & (x <= x_gate2)

for Vg_current in Vg_sweep:
    print("\n" + "="*60)
    print(f" STARTING SWEEP RUN (Vg = {Vg_current}V, Vds = {Vds}V) - RF Simulation")
    print("="*60)

    Id_history = []
    moving_avg_prev = None
    diverge_count = 0
    best_stable_Id = 0.0
    recent_trends = []  
    
    T_max_prev = T_amb
    I_d_prev = 0.0

    phi = np.zeros((Nz, Nx))
    n_2d = np.zeros((Nz, Nx))
    T_2d = np.full((Nz, Nx), T_amb)
    T_channel = np.full(Nx, T_amb)
    V_tot = np.copy(V_band)

    V_ef_lat = np.linspace(0, Vds, Nx)
    E_F_lat = -q * V_ef_lat

    idx_qbox = np.argmin(np.abs(z - (t_barrier + 95.0e-9)))

    dirichlet_mask = gate_mask | source_mask | drain_mask
    surface_pin_mask = (Z == 0) & ~dirichlet_mask
    outer_bc_mask = ((Z == Lz) | (X == 0) | (X == Lx)) & (Z > 0)
    interior_mask = ~(dirichlet_mask | surface_pin_mask | outer_bc_mask)

    N_DOS_3D_equiv = np.broadcast_to((m_GaN * kB * T_amb) / (np.pi * hbar**2 * dz_avg[:, np.newaxis]), (Nz, Nx))
    b_base_2d = np.zeros((Nz, Nx))
    b_base_2d[gate_mask] = Vg_current - (V_schottky - dE_c / q)
    b_base_2d[source_mask] = V_bi
    b_base_2d[drain_mask] = Vds + V_bi
    b_base_2d[surface_pin_mask] = V_surface_pin

    Ex_abs = np.zeros(Nx)
    mu_field = np.zeros(Nx)
    I_d_channel = np.zeros(Nx)
    I_d_avg = 0.0
    n_s_eff = np.zeros(Nx)

    for iteration in range(max_iter_limit):
        # A. Poisson Block
        b_2d = np.copy(b_base_2d)
        E_C = V_band - q * phi; E_A = E_C - E_dA
        E_Fn = E_F_lat[np.newaxis, :] 
        
        exp_term_A = g_A * np.exp(np.clip((E_A - E_Fn) / (kB * T_amb), -700.0, 700.0))
        f_A = 1.0 / (1.0 + exp_term_A) 
        
        rho_trap = np.zeros((Nz, Nx))
        rho_trap[buf_trap_mask] = -q * N_acceptor * f_A[buf_trap_mask]
        
        rho_total = rho_fixed + rho_trap
        b_2d[interior_mask] = -(rho_total[interior_mask] - q * n_2d[interior_mask])
        
        term_n = np.exp(-np.minimum(n_2d[interior_mask] / N_DOS_3D_equiv[interior_mask], 700.0))
        D_electrons = (q**2 * N_DOS_3D_equiv[interior_mask] / (kB * T_amb)) * (1.0 - term_n)
        
        exp_A_sub = exp_term_A[buf_trap_mask]
        df_dE = np.where(exp_A_sub > 1e15, 0.0, exp_A_sub / (1.0 + exp_A_sub)**2)
        
        D_traps = np.zeros((Nz, Nx))
        D_traps[buf_trap_mask] = (q**2 * N_acceptor / (kB * T_amb)) * df_dE
        
        D_gummel_2d = np.zeros((Nz, Nx))
        D_gummel_2d[interior_mask] = D_electrons + D_traps[interior_mask]
        
        D_gummel_flat = D_gummel_2d.flatten()
        A_gummel_dynamic = A_csr - sparse.diags(D_gummel_flat, format='csr')
        b_gummel_dynamic = b_2d.flatten() - D_gummel_flat * phi.flatten()
        
        phi_new = spla.spsolve(A_gummel_dynamic, b_gummel_dynamic).reshape((Nz, Nx))
        err_phi = np.max(np.abs(phi_new - phi))
        
        phi = alpha_p * phi_new + (1 - alpha_p) * phi
        V_tot = np.clip(V_band - q * phi, -15 * q, 5 * q) 
        
        # B. Schrödinger Block
        n_new = np.zeros((Nz, Nx))
        V_xc_raw = -(q**2 / (4.0 * np.pi * eps_r)) * (3.0 * np.maximum(n_2d, 1e12) / np.pi)**(1.0 / 3.0)
        V_xc = np.clip(V_xc_raw, -0.05 * q, 0.0)
        V_quantum_2d = V_tot + V_xc
        N_int = idx_qbox - 2
        
        for i in range(Nx):
            V_quantum = V_quantum_2d[:idx_qbox, i]; m_col = m_eff[:idx_qbox, i]
            d_int = np.zeros(N_int); e_int = np.zeros(N_int - 1)
            
            for k in range(N_int):
                j = k + 1
                dz_r, dz_l, dz_a = dz_R[j], dz_R[j-1], dz_avg[j]
                inv_mp, inv_mm = 0.5*(1.0/m_col[j] + 1.0/m_col[j+1]), 0.5*(1.0/m_col[j] + 1.0/m_col[j-1])
                d_int[k] = V_quantum[j] + (hbar**2 / (2.0 * dz_a)) * (inv_mp / dz_r + inv_mm / dz_l)
                if k < N_int - 1:
                    e_int[k] = -(hbar**2 / 2.0) * (inv_mp / dz_r) / np.sqrt(dz_a * dz_avg[j+1])
            
            evals, evecs_int = la.eigh_tridiagonal(d_int, e_int, select='i', select_range=(0, n_subbands-1))
            evecs_full = np.zeros((idx_qbox, n_subbands))
            evecs_full[1:-1, :] = evecs_int
            
            for m in range(n_subbands):
                m_eff_subband = m_GaN * (1.0 + (0.6/q) * np.maximum(evals[m] - V_quantum[idx_int], 0.0))
                n_s = ((m_eff_subband * kB * T_amb) / (np.pi * hbar**2)) * np.logaddexp(0, (E_F_lat[i] - evals[m]) / (kB * T_amb))
                u_sq = evecs_full[:, m]**2
                psi_sq = (u_sq / dz_avg[:idx_qbox]) / np.sum(u_sq)
                psi_sq_full = np.zeros(Nz); psi_sq_full[:idx_qbox] = psi_sq
                n_new[:, i] += n_s * psi_sq_full 
                
        n_2d = alpha_n * n_new + (1 - alpha_n) * n_2d  
        
        # C. Electro-Thermal Transport Block
        n_s_eff = np.maximum(np.sum(n_2d * dz_avg[:, np.newaxis], axis=0), 1e10)
        
        mu_T_scale = (T_amb / T_channel)**gamma_mu
        v_sat_T_scale = (T_amb / T_channel)**gamma_vsat
        
        mu_pop, mu_dis, mu_irs, n_ref = 0.15, 0.20, 0.10, 1.0e17        
        inv_mu_dis = 1.0 / (mu_dis * (n_s_eff / n_ref)**0.5)
        inv_mu_pop = 1.0 / mu_pop
        inv_mu_irs = 1.0 / (mu_irs * (n_ref / n_s_eff)**2.5)
        
        mu_0_lat = (1.0 / (inv_mu_dis + inv_mu_pop + inv_mu_irs)) * mu_T_scale
        v_sat_lat = v_sat_300K * v_sat_T_scale
        
        Ex = np.zeros(Nx)
        Ex[1:-1] = -(phi[idx_int, 2:] - phi[idx_int, :-2]) / (x[2:] - x[:-2])
        Ex[0] = -(phi[idx_int, 1] - phi[idx_int, 0]) / dx_R[0]
        Ex[-1] = -(phi[idx_int, -1] - phi[idx_int, -2]) / dx_R[-1]
        Ex_abs = np.maximum(np.abs(Ex), 1e2)  
        
        den_mobility = (1.0 + (mu_0_lat * Ex_abs / v_sat_lat)**beta_CT)**(1.0 / beta_CT)
        mu_field = mu_0_lat / den_mobility
        G_eff = n_s_eff * mu_field
        
        G_mid = 2.0 * (G_eff[:-1] * G_eff[1:]) / (G_eff[:-1] + G_eff[1:] + 1e-30)
        R_c = 1.2e-3  
        
        I_est = np.mean(I_d_channel[1:-1]) if iteration > 0 else 1000.0 
        V_s_eff = (I_est * 1e-3) * R_c
        V_d_eff = Vds - (I_est * 1e-3) * R_c
        
        A_1D = sparse.lil_matrix((Nx, Nx)); b_1D = np.zeros(Nx)
        for i in range(Nx):
            if i == 0: 
                A_1D[i, i] = 1.0; b_1D[i] = V_s_eff  
            elif i == Nx - 1: 
                A_1D[i, i] = 1.0; b_1D[i] = V_d_eff  
            else:
                lc, rc = G_mid[i - 1] / dx_R[i - 1], G_mid[i] / dx_R[i]
                A_1D[i, i - 1] = lc; A_1D[i, i + 1] = rc; A_1D[i, i] = -(lc + rc)
                
        V_ef_new = spla.spsolve(A_1D.tocsr(), b_1D)
        V_ef_lat = alpha_EF * V_ef_new + (1 - alpha_EF) * V_ef_lat
        E_F_lat = -q * V_ef_lat
        
        dVef_dx = np.zeros(Nx)
        dVef_dx[1:-1] = (V_ef_lat[2:] - V_ef_lat[:-2]) / (x[2:] - x[:-2])
        dVef_dx[0], dVef_dx[-1] = (V_ef_lat[1]-V_ef_lat[0])/dx_R[0], (V_ef_lat[-1]-V_ef_lat[-2])/dx_R[-1]
        
        I_d_channel = q * G_eff * dVef_dx        
        I_d_avg = np.mean(I_d_channel[1:-1])
        
        P_diss_vol = (I_d_channel * Ex_abs) / dz_avg[idx_int] 
        
        b_therm = np.zeros(N_tot)
        for i in range(1, Nx-1):
            b_therm[get_k(i, idx_int)] = -P_diss_vol[i] 
        for i in range(Nx):
            b_therm[get_k(i, Nz-1)] = T_amb 
            
        T_flat = spla.spsolve(A_therm_csr, b_therm)
        T_2d_new = T_flat.reshape((Nz, Nx))
        
        dT = np.clip(T_2d_new - T_2d, -10.0, 10.0)
        T_2d = T_2d + alpha_T * dT
        T_channel = T_2d[idx_int, :]
        
        # --- D. Iteration Status & Windowed Trend Analysis ---
        if iteration % 10 == 0:
            peak_ns_cm2 = np.max(n_s_eff) / 1e4
            print(f"Iter {iteration:3d} | ΔV: {err_phi*1e3:.2f}mV | Max Temp: {np.max(T_channel):.1f}K | I_D: {I_d_avg:.1f} mA/mm | Max n_s: {peak_ns_cm2:.2e} cm^-2")
            
        Id_history.append(I_d_avg)
        if len(Id_history) > window_size:
            Id_history.pop(0)

        if np.isnan(I_d_avg) or np.isinf(I_d_avg):
            print(f"\n[!] Fatal breakdown (NaN/Inf) at iter {iteration}.")
            I_d_avg = best_stable_Id if best_stable_Id != 0.0 else I_d_prev
            break

        if len(Id_history) == window_size:
            window_max = np.max(Id_history)
            window_min = np.min(Id_history)
            moving_avg = np.mean(Id_history)

            if (window_max - window_min) < convergence_tol and iteration >= min_iters:
                print(f"\n[+] Converged successfully at iter {iteration} (ΔI_D < {convergence_tol} mA/mm).")
                I_d_avg = moving_avg  
                break

            if moving_avg_prev is not None:
                if moving_avg < moving_avg_prev:
                    recent_trends.append(-1)
                elif moving_avg > moving_avg_prev:
                    recent_trends.append(1)
                else:
                    recent_trends.append(0)

                if len(recent_trends) > trend_window_size:
                    recent_trends.pop(0)

                decrease_count = recent_trends.count(-1)

                if moving_avg > moving_avg_prev:
                    diverge_count += 1
                else:
                    diverge_count = 0
                    best_stable_Id = moving_avg  

                if diverge_count >= max_diverge_steps and decrease_count >= max_diverge_steps and iteration >= min_iters:
                    print(f"\n[!] Divergence detected at iter {iteration}. Rolling back to stable moving average: {best_stable_Id:.2f} mA/mm.")
                    I_d_avg = best_stable_Id
                    break

            moving_avg_prev = moving_avg

        if iteration == max_iter_limit - 1:
            print(f"\n[+] Finished run of {max_iter_limit} iterations for Vg = {Vg_current}V.")

        T_max_prev = np.max(T_channel)
        I_d_prev = I_d_avg

    # 2DEG Gate charge per unit width (C/m)
    Q_gate = q * np.sum(n_s_eff[gate_x_mask] * dx_avg[gate_x_mask])

    extracted_Vg.append(Vg_current)
    extracted_Id.append(I_d_avg)
    extracted_Qg.append(Q_gate)


# 6. PHYSICAL RF SMALL-SIGNAL MODEL (fT & fmax)
sorted_indices = np.argsort(extracted_Vg)
Vg_arr = np.array(extracted_Vg)[sorted_indices]
Id_arr = np.array(extracted_Id)[sorted_indices]      # mA/mm = A/m
Qg_arr = np.array(extracted_Qg)[sorted_indices]      # C/m

# Transconductance g_m (S/m = mS/mm)
gm_arr = np.gradient(Id_arr, Vg_arr)
gm_arr = np.maximum(gm_arr, 0.0)

# Physical Series + Parasitic Capacitance Model
eps_AlGaN_val = (8.5 * x_al + 8.9 * (1.0 - x_al)) * eps0
C_barr = (eps_AlGaN_val / t_barrier) * L_g  # Barrier capacitance

# Channel Quantum Capacitance C_quantum = dQg / dVg
C_quantum = np.abs(np.gradient(Qg_arr, Vg_arr))

# Intrinsic Gate Capacitance
C_int = (C_barr * C_quantum) / (C_barr + C_quantum + 1e-20)

# 1. Calibrated Fringing/Parasitic Capacitance (T-gates)
C_ext = 0.28e-9  # F/m

# Total Gate Capacitance
Cgg_arr = C_int + C_ext  # Total Gate Capacitance (F/m)

# Realistic Capacitance Partitioning
C_gd = 0.18 * Cgg_arr
C_gs = 0.82 * Cgg_arr

# 2. Calibrated RF Parasitics
R_g = 4.5e-3      # Gate metal resistance (4.5 Ohm-mm for sub-50nm T-stem)
R_s = 0.50e-3     # Source resistance (0.50 Ohm-mm)
R_d = 0.50e-3     # Drain resistance (0.50 Ohm-mm)

# 3. Short-Channel Output Conductance (DIBL & Buffer Punch-through)
g_ds = np.maximum(0.15 * gm_arr, 15.0)  # g_ds / g_m ~ 0.15 (S/m)

# 4. High-Field Drain Depletion Transit Time Delay (~0.25 ps)
tau_d = 0.25e-12  # Transit delay in seconds

# Total RF Delay tau = tau_channel + tau_drain + tau_charging
tau_total = (C_gs + C_gd) / (gm_arr + 1e-20) + tau_d + (R_s + R_d) * C_gd

# Cut-off Frequency f_T with parasitic feedback
fT_Hz = 1.0 / (2.0 * np.pi * tau_total * np.sqrt(1 + 2 * g_ds * R_s))

# Maximum Oscillation Frequency f_max
denom_fmax = 2.0 * np.sqrt((R_g + R_s) * g_ds + 2.0 * np.pi * fT_Hz * R_g * C_gd + 1e-20)
fmax_Hz = fT_Hz / np.maximum(denom_fmax, 1e-10)

# Mask out subthreshold region (Id < 15 mA/mm)
pinch_mask = Id_arr < 15.0
fT_GHz = np.where(pinch_mask, 0.0, fT_Hz / 1e9)
fmax_GHz = np.where(pinch_mask, 0.0, fmax_Hz / 1e9)


# 7. fT AND fmax PLOT
fig, ax1 = plt.subplots(figsize=(9, 6))

color1 = 'tab:blue'
ax1.set_xlabel('Gate-Source Voltage, $V_{GS}$ (V)', fontweight='bold', fontsize=12)
ax1.set_ylabel('Cut-off Frequency, $f_T$ (GHz)', color=color1, fontweight='bold', fontsize=12)
line1, = ax1.plot(Vg_arr, fT_GHz, 'o-', color=color1, linewidth=2, markersize=7, label='$f_T$')
ax1.tick_params(axis='y', labelcolor=color1)
ax1.grid(True, linestyle='--', alpha=0.6)

ax2 = ax1.twinx()
color2 = 'tab:red'
ax2.set_ylabel('Max Oscillation Frequency, $f_{max}$ (GHz)', color=color2, fontweight='bold', fontsize=12)
line2, = ax2.plot(Vg_arr, fmax_GHz, 's--', color=color2, linewidth=2, markersize=7, label='$f_{max}$')
ax2.tick_params(axis='y', labelcolor=color2)

lines = [line1, line2]
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='upper left', fontsize=11)

plt.title(f'High-Frequency Characteristics ($L_g = 30$ nm, $V_{{DS}} = {Vds}$ V)', fontweight='bold', fontsize=14)
fig.tight_layout()
plt.show()
# Out:
# ============================================================
#  STARTING SWEEP RUN (Vg = 2.0V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5947.72mV | Max Temp: 300.0K | I_D: 47.8 mA/mm | Max n_s: 1.21e+12 cm^-2
# Iter  10 | ΔV: 1747.66mV | Max Temp: 301.3K | I_D: 1156.9 mA/mm | Max n_s: 2.05e+13 cm^-2
# Iter  20 | ΔV: 864.24mV | Max Temp: 303.3K | I_D: 2638.3 mA/mm | Max n_s: 3.87e+13 cm^-2
# Iter  30 | ΔV: 494.99mV | Max Temp: 305.3K | I_D: 2589.3 mA/mm | Max n_s: 5.43e+13 cm^-2
# Iter  40 | ΔV: 287.03mV | Max Temp: 307.3K | I_D: 2269.3 mA/mm | Max n_s: 6.63e+13 cm^-2
# Iter  50 | ΔV: 166.63mV | Max Temp: 309.3K | I_D: 2126.4 mA/mm | Max n_s: 7.53e+13 cm^-2
# Iter  60 | ΔV: 98.50mV | Max Temp: 311.3K | I_D: 2107.1 mA/mm | Max n_s: 8.18e+13 cm^-2
# Iter  70 | ΔV: 58.97mV | Max Temp: 313.3K | I_D: 2202.2 mA/mm | Max n_s: 8.62e+13 cm^-2
# Iter  80 | ΔV: 56.17mV | Max Temp: 315.3K | I_D: 2380.1 mA/mm | Max n_s: 8.89e+13 cm^-2
# Iter  90 | ΔV: 55.71mV | Max Temp: 317.3K | I_D: 2579.6 mA/mm | Max n_s: 9.03e+13 cm^-2
# Iter 100 | ΔV: 55.33mV | Max Temp: 319.3K | I_D: 2734.2 mA/mm | Max n_s: 9.06e+13 cm^-2
# Iter 110 | ΔV: 54.81mV | Max Temp: 321.3K | I_D: 2794.4 mA/mm | Max n_s: 9.00e+13 cm^-2
# Iter 120 | ΔV: 53.71mV | Max Temp: 323.3K | I_D: 2741.6 mA/mm | Max n_s: 8.89e+13 cm^-2
# Iter 130 | ΔV: 52.05mV | Max Temp: 325.3K | I_D: 2592.7 mA/mm | Max n_s: 8.73e+13 cm^-2
# Iter 140 | ΔV: 49.07mV | Max Temp: 327.3K | I_D: 2384.6 mA/mm | Max n_s: 8.54e+13 cm^-2
# Iter 150 | ΔV: 43.99mV | Max Temp: 329.3K | I_D: 2150.9 mA/mm | Max n_s: 8.33e+13 cm^-2
# Iter 160 | ΔV: 36.92mV | Max Temp: 331.3K | I_D: 1913.8 mA/mm | Max n_s: 8.11e+13 cm^-2
# Iter 170 | ΔV: 28.36mV | Max Temp: 333.3K | I_D: 1686.7 mA/mm | Max n_s: 7.89e+13 cm^-2
# Iter 180 | ΔV: 21.12mV | Max Temp: 335.3K | I_D: 1481.1 mA/mm | Max n_s: 7.66e+13 cm^-2
# Iter 190 | ΔV: 28.79mV | Max Temp: 337.3K | I_D: 1307.5 mA/mm | Max n_s: 7.44e+13 cm^-2
# Iter 200 | ΔV: 36.45mV | Max Temp: 339.2K | I_D: 1170.4 mA/mm | Max n_s: 7.23e+13 cm^-2
# Iter 210 | ΔV: 41.05mV | Max Temp: 340.8K | I_D: 1078.6 mA/mm | Max n_s: 7.02e+13 cm^-2
# Iter 220 | ΔV: 35.13mV | Max Temp: 341.9K | I_D: 1058.1 mA/mm | Max n_s: 6.83e+13 cm^-2
# Iter 230 | ΔV: 32.14mV | Max Temp: 343.0K | I_D: 1157.1 mA/mm | Max n_s: 6.63e+13 cm^-2
# Iter 240 | ΔV: 48.26mV | Max Temp: 344.8K | I_D: 1404.7 mA/mm | Max n_s: 6.45e+13 cm^-2
# Iter 250 | ΔV: 61.14mV | Max Temp: 346.8K | I_D: 1630.3 mA/mm | Max n_s: 6.27e+13 cm^-2
# Iter 260 | ΔV: 63.14mV | Max Temp: 348.8K | I_D: 1633.6 mA/mm | Max n_s: 6.09e+13 cm^-2
# Iter 270 | ΔV: 54.64mV | Max Temp: 350.8K | I_D: 1590.4 mA/mm | Max n_s: 5.92e+13 cm^-2
#
# [!] Divergence detected at iter 278. Rolling back to stable moving average: 1588.20 mA/mm.
#
# ============================================================
#  STARTING SWEEP RUN (Vg = 1.5V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5884.71mV | Max Temp: 300.0K | I_D: 45.0 mA/mm | Max n_s: 1.18e+12 cm^-2
# Iter  10 | ΔV: 1784.41mV | Max Temp: 301.2K | I_D: 1066.2 mA/mm | Max n_s: 2.03e+13 cm^-2
# Iter  20 | ΔV: 864.31mV | Max Temp: 303.2K | I_D: 2189.3 mA/mm | Max n_s: 3.83e+13 cm^-2
# Iter  30 | ΔV: 495.17mV | Max Temp: 305.2K | I_D: 2584.9 mA/mm | Max n_s: 5.38e+13 cm^-2
# Iter  40 | ΔV: 287.14mV | Max Temp: 307.2K | I_D: 2249.4 mA/mm | Max n_s: 6.58e+13 cm^-2
# Iter  50 | ΔV: 172.54mV | Max Temp: 309.2K | I_D: 2093.5 mA/mm | Max n_s: 7.48e+13 cm^-2
# Iter  60 | ΔV: 103.54mV | Max Temp: 311.2K | I_D: 2072.1 mA/mm | Max n_s: 8.12e+13 cm^-2
# Iter  70 | ΔV: 58.97mV | Max Temp: 313.2K | I_D: 2168.9 mA/mm | Max n_s: 8.56e+13 cm^-2
# Iter  80 | ΔV: 54.48mV | Max Temp: 315.2K | I_D: 2356.8 mA/mm | Max n_s: 8.83e+13 cm^-2
# Iter  90 | ΔV: 52.28mV | Max Temp: 317.2K | I_D: 2571.0 mA/mm | Max n_s: 8.96e+13 cm^-2
# Iter 100 | ΔV: 52.25mV | Max Temp: 319.2K | I_D: 2731.9 mA/mm | Max n_s: 8.99e+13 cm^-2
# Iter 110 | ΔV: 52.03mV | Max Temp: 321.2K | I_D: 2778.8 mA/mm | Max n_s: 8.94e+13 cm^-2
# Iter 120 | ΔV: 51.08mV | Max Temp: 323.2K | I_D: 2692.6 mA/mm | Max n_s: 8.82e+13 cm^-2
# Iter 130 | ΔV: 48.92mV | Max Temp: 325.2K | I_D: 2501.3 mA/mm | Max n_s: 8.66e+13 cm^-2
# Iter 140 | ΔV: 45.31mV | Max Temp: 327.2K | I_D: 2257.1 mA/mm | Max n_s: 8.47e+13 cm^-2
# Iter 150 | ΔV: 40.29mV | Max Temp: 329.2K | I_D: 2003.8 mA/mm | Max n_s: 8.26e+13 cm^-2
# Iter 160 | ΔV: 33.42mV | Max Temp: 331.2K | I_D: 1767.2 mA/mm | Max n_s: 8.04e+13 cm^-2
# Iter 170 | ΔV: 25.22mV | Max Temp: 333.2K | I_D: 1559.8 mA/mm | Max n_s: 7.82e+13 cm^-2
# Iter 180 | ΔV: 20.59mV | Max Temp: 335.2K | I_D: 1386.0 mA/mm | Max n_s: 7.60e+13 cm^-2
# Iter 190 | ΔV: 28.04mV | Max Temp: 337.2K | I_D: 1244.4 mA/mm | Max n_s: 7.38e+13 cm^-2
# Iter 200 | ΔV: 35.74mV | Max Temp: 339.0K | I_D: 1131.8 mA/mm | Max n_s: 7.17e+13 cm^-2
# Iter 210 | ΔV: 41.55mV | Max Temp: 340.4K | I_D: 1051.2 mA/mm | Max n_s: 6.97e+13 cm^-2
# Iter 220 | ΔV: 37.05mV | Max Temp: 341.1K | I_D: 1027.7 mA/mm | Max n_s: 6.77e+13 cm^-2
# Iter 230 | ΔV: 30.72mV | Max Temp: 341.8K | I_D: 1129.5 mA/mm | Max n_s: 6.58e+13 cm^-2
# Iter 240 | ΔV: 47.43mV | Max Temp: 343.3K | I_D: 1396.6 mA/mm | Max n_s: 6.40e+13 cm^-2
# Iter 250 | ΔV: 62.99mV | Max Temp: 345.3K | I_D: 1616.3 mA/mm | Max n_s: 6.22e+13 cm^-2
# Iter 260 | ΔV: 67.24mV | Max Temp: 347.3K | I_D: 1619.8 mA/mm | Max n_s: 6.04e+13 cm^-2
# Iter 270 | ΔV: 60.80mV | Max Temp: 349.3K | I_D: 1577.5 mA/mm | Max n_s: 5.87e+13 cm^-2
#
# [!] Divergence detected at iter 278. Rolling back to stable moving average: 1575.41 mA/mm.
#
# ============================================================
#  STARTING SWEEP RUN (Vg = 1.0V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5821.70mV | Max Temp: 300.0K | I_D: 42.2 mA/mm | Max n_s: 1.15e+12 cm^-2
# Iter  10 | ΔV: 1833.33mV | Max Temp: 301.2K | I_D: 998.0 mA/mm | Max n_s: 2.00e+13 cm^-2
# Iter  20 | ΔV: 864.49mV | Max Temp: 303.2K | I_D: 1843.9 mA/mm | Max n_s: 3.78e+13 cm^-2
# Iter  30 | ΔV: 495.36mV | Max Temp: 305.2K | I_D: 2518.2 mA/mm | Max n_s: 5.32e+13 cm^-2
# Iter  40 | ΔV: 287.25mV | Max Temp: 307.2K | I_D: 2222.2 mA/mm | Max n_s: 6.52e+13 cm^-2
# Iter  50 | ΔV: 179.01mV | Max Temp: 309.2K | I_D: 2045.3 mA/mm | Max n_s: 7.41e+13 cm^-2
# Iter  60 | ΔV: 110.32mV | Max Temp: 311.2K | I_D: 2016.8 mA/mm | Max n_s: 8.05e+13 cm^-2
# Iter  70 | ΔV: 61.66mV | Max Temp: 313.2K | I_D: 2111.0 mA/mm | Max n_s: 8.49e+13 cm^-2
# Iter  80 | ΔV: 52.69mV | Max Temp: 315.2K | I_D: 2305.4 mA/mm | Max n_s: 8.76e+13 cm^-2
# Iter  90 | ΔV: 50.68mV | Max Temp: 317.2K | I_D: 2536.4 mA/mm | Max n_s: 8.89e+13 cm^-2
# Iter 100 | ΔV: 49.46mV | Max Temp: 319.2K | I_D: 2711.8 mA/mm | Max n_s: 8.92e+13 cm^-2
# Iter 110 | ΔV: 49.12mV | Max Temp: 321.2K | I_D: 2753.7 mA/mm | Max n_s: 8.86e+13 cm^-2
# Iter 120 | ΔV: 47.94mV | Max Temp: 323.2K | I_D: 2643.5 mA/mm | Max n_s: 8.75e+13 cm^-2
# Iter 130 | ΔV: 45.46mV | Max Temp: 325.2K | I_D: 2428.6 mA/mm | Max n_s: 8.58e+13 cm^-2
# Iter 140 | ΔV: 41.36mV | Max Temp: 327.2K | I_D: 2175.1 mA/mm | Max n_s: 8.39e+13 cm^-2
# Iter 150 | ΔV: 36.05mV | Max Temp: 329.2K | I_D: 1923.2 mA/mm | Max n_s: 8.19e+13 cm^-2
# Iter 160 | ΔV: 29.16mV | Max Temp: 331.2K | I_D: 1691.3 mA/mm | Max n_s: 7.97e+13 cm^-2
# Iter 170 | ΔV: 22.62mV | Max Temp: 333.2K | I_D: 1488.8 mA/mm | Max n_s: 7.75e+13 cm^-2
# Iter 180 | ΔV: 19.86mV | Max Temp: 335.2K | I_D: 1320.2 mA/mm | Max n_s: 7.53e+13 cm^-2
# Iter 190 | ΔV: 24.73mV | Max Temp: 337.2K | I_D: 1185.2 mA/mm | Max n_s: 7.31e+13 cm^-2
# Iter 200 | ΔV: 31.76mV | Max Temp: 338.9K | I_D: 1082.8 mA/mm | Max n_s: 7.10e+13 cm^-2
# Iter 210 | ΔV: 37.76mV | Max Temp: 340.1K | I_D: 1013.7 mA/mm | Max n_s: 6.90e+13 cm^-2
# Iter 220 | ΔV: 37.19mV | Max Temp: 340.5K | I_D: 985.6 mA/mm | Max n_s: 6.71e+13 cm^-2
# Iter 230 | ΔV: 29.19mV | Max Temp: 340.7K | I_D: 1048.6 mA/mm | Max n_s: 6.52e+13 cm^-2
# Iter 240 | ΔV: 42.54mV | Max Temp: 341.6K | I_D: 1286.4 mA/mm | Max n_s: 6.33e+13 cm^-2
# Iter 250 | ΔV: 61.72mV | Max Temp: 343.5K | I_D: 1608.3 mA/mm | Max n_s: 6.16e+13 cm^-2
# Iter 260 | ΔV: 72.23mV | Max Temp: 345.5K | I_D: 1617.3 mA/mm | Max n_s: 5.98e+13 cm^-2
# Iter 270 | ΔV: 69.53mV | Max Temp: 347.5K | I_D: 1519.8 mA/mm | Max n_s: 5.81e+13 cm^-2
# Iter 280 | ΔV: 55.95mV | Max Temp: 349.5K | I_D: 1510.7 mA/mm | Max n_s: 5.65e+13 cm^-2
#
# [!] Divergence detected at iter 281. Rolling back to stable moving average: 1504.61 mA/mm.
#
# ============================================================
#  STARTING SWEEP RUN (Vg = 0.5V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5758.69mV | Max Temp: 300.0K | I_D: 39.5 mA/mm | Max n_s: 1.12e+12 cm^-2
# Iter  10 | ΔV: 1899.74mV | Max Temp: 301.2K | I_D: 938.3 mA/mm | Max n_s: 1.96e+13 cm^-2
# Iter  20 | ΔV: 864.78mV | Max Temp: 303.2K | I_D: 1580.3 mA/mm | Max n_s: 3.73e+13 cm^-2
# Iter  30 | ΔV: 495.54mV | Max Temp: 305.2K | I_D: 2329.2 mA/mm | Max n_s: 5.25e+13 cm^-2
# Iter  40 | ΔV: 287.32mV | Max Temp: 307.2K | I_D: 2198.8 mA/mm | Max n_s: 6.43e+13 cm^-2
# Iter  50 | ΔV: 184.88mV | Max Temp: 309.2K | I_D: 1991.7 mA/mm | Max n_s: 7.32e+13 cm^-2
# Iter  60 | ΔV: 117.32mV | Max Temp: 311.2K | I_D: 1948.6 mA/mm | Max n_s: 7.95e+13 cm^-2
# Iter  70 | ΔV: 68.51mV | Max Temp: 313.2K | I_D: 2034.6 mA/mm | Max n_s: 8.38e+13 cm^-2
# Iter  80 | ΔV: 53.05mV | Max Temp: 315.2K | I_D: 2230.2 mA/mm | Max n_s: 8.64e+13 cm^-2
# Iter  90 | ΔV: 50.04mV | Max Temp: 317.2K | I_D: 2478.2 mA/mm | Max n_s: 8.77e+13 cm^-2
# Iter 100 | ΔV: 48.79mV | Max Temp: 319.2K | I_D: 2675.7 mA/mm | Max n_s: 8.80e+13 cm^-2
# Iter 110 | ΔV: 47.29mV | Max Temp: 321.2K | I_D: 2724.9 mA/mm | Max n_s: 8.75e+13 cm^-2
# Iter 120 | ΔV: 45.93mV | Max Temp: 323.2K | I_D: 2608.3 mA/mm | Max n_s: 8.63e+13 cm^-2
# Iter 130 | ΔV: 43.11mV | Max Temp: 325.2K | I_D: 2391.3 mA/mm | Max n_s: 8.48e+13 cm^-2
# Iter 140 | ΔV: 38.64mV | Max Temp: 327.2K | I_D: 2142.3 mA/mm | Max n_s: 8.29e+13 cm^-2
# Iter 150 | ΔV: 32.62mV | Max Temp: 329.2K | I_D: 1895.5 mA/mm | Max n_s: 8.08e+13 cm^-2
# Iter 160 | ΔV: 26.11mV | Max Temp: 331.2K | I_D: 1666.4 mA/mm | Max n_s: 7.87e+13 cm^-2
# Iter 170 | ΔV: 24.21mV | Max Temp: 333.2K | I_D: 1463.7 mA/mm | Max n_s: 7.65e+13 cm^-2
# Iter 180 | ΔV: 21.82mV | Max Temp: 335.2K | I_D: 1293.5 mA/mm | Max n_s: 7.43e+13 cm^-2
# Iter 190 | ΔV: 19.55mV | Max Temp: 337.2K | I_D: 1157.9 mA/mm | Max n_s: 7.22e+13 cm^-2
# Iter 200 | ΔV: 25.39mV | Max Temp: 338.8K | I_D: 1056.8 mA/mm | Max n_s: 7.01e+13 cm^-2
# Iter 210 | ΔV: 30.81mV | Max Temp: 339.9K | I_D: 989.2 mA/mm | Max n_s: 6.81e+13 cm^-2
# Iter 220 | ΔV: 33.57mV | Max Temp: 340.0K | I_D: 951.1 mA/mm | Max n_s: 6.62e+13 cm^-2
# Iter 230 | ΔV: 28.50mV | Max Temp: 339.7K | I_D: 961.5 mA/mm | Max n_s: 6.43e+13 cm^-2
# Iter 240 | ΔV: 31.11mV | Max Temp: 339.8K | I_D: 1079.8 mA/mm | Max n_s: 6.26e+13 cm^-2
# Iter 250 | ΔV: 51.53mV | Max Temp: 340.8K | I_D: 1357.9 mA/mm | Max n_s: 6.08e+13 cm^-2
# Iter 260 | ΔV: 69.33mV | Max Temp: 342.8K | I_D: 1585.6 mA/mm | Max n_s: 5.91e+13 cm^-2
# Iter 270 | ΔV: 77.46mV | Max Temp: 344.8K | I_D: 1473.4 mA/mm | Max n_s: 5.74e+13 cm^-2
# Iter 280 | ΔV: 71.21mV | Max Temp: 346.8K | I_D: 1402.9 mA/mm | Max n_s: 5.58e+13 cm^-2
#
# [!] Divergence detected at iter 286. Rolling back to stable moving average: 1403.89 mA/mm.
#
# ============================================================
#  STARTING SWEEP RUN (Vg = 0.0V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5695.67mV | Max Temp: 300.0K | I_D: 37.0 mA/mm | Max n_s: 1.09e+12 cm^-2
# Iter  10 | ΔV: 1988.80mV | Max Temp: 301.1K | I_D: 876.9 mA/mm | Max n_s: 1.93e+13 cm^-2
# Iter  20 | ΔV: 865.20mV | Max Temp: 303.1K | I_D: 1383.3 mA/mm | Max n_s: 3.68e+13 cm^-2
# Iter  30 | ΔV: 495.68mV | Max Temp: 305.1K | I_D: 2010.4 mA/mm | Max n_s: 5.19e+13 cm^-2
# Iter  40 | ΔV: 287.40mV | Max Temp: 307.1K | I_D: 2154.6 mA/mm | Max n_s: 6.36e+13 cm^-2
# Iter  50 | ΔV: 196.59mV | Max Temp: 309.1K | I_D: 1926.9 mA/mm | Max n_s: 7.23e+13 cm^-2
# Iter  60 | ΔV: 130.67mV | Max Temp: 311.1K | I_D: 1853.8 mA/mm | Max n_s: 7.85e+13 cm^-2
# Iter  70 | ΔV: 79.48mV | Max Temp: 313.1K | I_D: 1920.3 mA/mm | Max n_s: 8.28e+13 cm^-2
# Iter  80 | ΔV: 60.03mV | Max Temp: 315.1K | I_D: 2106.4 mA/mm | Max n_s: 8.54e+13 cm^-2
# Iter  90 | ΔV: 48.85mV | Max Temp: 317.1K | I_D: 2368.0 mA/mm | Max n_s: 8.67e+13 cm^-2
# Iter 100 | ΔV: 46.99mV | Max Temp: 319.1K | I_D: 2600.9 mA/mm | Max n_s: 8.69e+13 cm^-2
# Iter 110 | ΔV: 45.43mV | Max Temp: 321.1K | I_D: 2684.5 mA/mm | Max n_s: 8.64e+13 cm^-2
# Iter 120 | ΔV: 43.50mV | Max Temp: 323.1K | I_D: 2591.0 mA/mm | Max n_s: 8.53e+13 cm^-2
# Iter 130 | ΔV: 40.48mV | Max Temp: 325.1K | I_D: 2393.2 mA/mm | Max n_s: 8.37e+13 cm^-2
# Iter 140 | ΔV: 35.93mV | Max Temp: 327.1K | I_D: 2160.8 mA/mm | Max n_s: 8.18e+13 cm^-2
# Iter 150 | ΔV: 30.03mV | Max Temp: 329.1K | I_D: 1923.8 mA/mm | Max n_s: 7.97e+13 cm^-2
# Iter 160 | ΔV: 27.75mV | Max Temp: 331.1K | I_D: 1694.8 mA/mm | Max n_s: 7.76e+13 cm^-2
# Iter 170 | ΔV: 26.03mV | Max Temp: 333.1K | I_D: 1485.0 mA/mm | Max n_s: 7.54e+13 cm^-2
# Iter 180 | ΔV: 23.94mV | Max Temp: 335.1K | I_D: 1303.9 mA/mm | Max n_s: 7.32e+13 cm^-2
# Iter 190 | ΔV: 21.94mV | Max Temp: 337.1K | I_D: 1158.1 mA/mm | Max n_s: 7.11e+13 cm^-2
# Iter 200 | ΔV: 18.97mV | Max Temp: 338.7K | I_D: 1050.9 mA/mm | Max n_s: 6.91e+13 cm^-2
# Iter 210 | ΔV: 21.51mV | Max Temp: 339.9K | I_D: 982.4 mA/mm | Max n_s: 6.71e+13 cm^-2
# Iter 220 | ΔV: 24.80mV | Max Temp: 339.9K | I_D: 943.3 mA/mm | Max n_s: 6.52e+13 cm^-2
# Iter 230 | ΔV: 26.08mV | Max Temp: 339.2K | I_D: 929.7 mA/mm | Max n_s: 6.34e+13 cm^-2
# Iter 240 | ΔV: 25.11mV | Max Temp: 338.4K | I_D: 963.4 mA/mm | Max n_s: 6.17e+13 cm^-2
# Iter 250 | ΔV: 32.84mV | Max Temp: 338.1K | I_D: 1086.9 mA/mm | Max n_s: 6.00e+13 cm^-2
# Iter 260 | ΔV: 51.16mV | Max Temp: 338.7K | I_D: 1296.5 mA/mm | Max n_s: 5.83e+13 cm^-2
# Iter 270 | ΔV: 69.25mV | Max Temp: 340.5K | I_D: 1404.5 mA/mm | Max n_s: 5.67e+13 cm^-2
# Iter 280 | ΔV: 80.57mV | Max Temp: 342.5K | I_D: 1319.4 mA/mm | Max n_s: 5.51e+13 cm^-2
# Iter 290 | ΔV: 77.36mV | Max Temp: 344.5K | I_D: 1286.6 mA/mm | Max n_s: 5.36e+13 cm^-2
#
# [!] Divergence detected at iter 293. Rolling back to stable moving average: 1284.90 mA/mm.
#
# ============================================================
#  STARTING SWEEP RUN (Vg = -0.5V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5632.66mV | Max Temp: 300.0K | I_D: 34.6 mA/mm | Max n_s: 1.06e+12 cm^-2
# Iter  10 | ΔV: 2107.56mV | Max Temp: 301.1K | I_D: 794.6 mA/mm | Max n_s: 1.90e+13 cm^-2
# Iter  20 | ΔV: 865.61mV | Max Temp: 303.1K | I_D: 1273.0 mA/mm | Max n_s: 3.63e+13 cm^-2
# Iter  30 | ΔV: 495.76mV | Max Temp: 305.1K | I_D: 1695.1 mA/mm | Max n_s: 5.13e+13 cm^-2
# Iter  40 | ΔV: 292.42mV | Max Temp: 307.1K | I_D: 1987.8 mA/mm | Max n_s: 6.29e+13 cm^-2
# Iter  50 | ΔV: 207.63mV | Max Temp: 309.1K | I_D: 1843.2 mA/mm | Max n_s: 7.16e+13 cm^-2
# Iter  60 | ΔV: 142.31mV | Max Temp: 311.1K | I_D: 1713.9 mA/mm | Max n_s: 7.78e+13 cm^-2
# Iter  70 | ΔV: 91.26mV | Max Temp: 313.1K | I_D: 1734.3 mA/mm | Max n_s: 8.20e+13 cm^-2
# Iter  80 | ΔV: 70.15mV | Max Temp: 315.1K | I_D: 1884.2 mA/mm | Max n_s: 8.45e+13 cm^-2
# Iter  90 | ΔV: 58.71mV | Max Temp: 317.1K | I_D: 2139.9 mA/mm | Max n_s: 8.58e+13 cm^-2
# Iter 100 | ΔV: 47.87mV | Max Temp: 319.1K | I_D: 2421.9 mA/mm | Max n_s: 8.61e+13 cm^-2
# Iter 110 | ΔV: 44.68mV | Max Temp: 321.1K | I_D: 2595.8 mA/mm | Max n_s: 8.55e+13 cm^-2
# Iter 120 | ΔV: 41.75mV | Max Temp: 323.1K | I_D: 2589.0 mA/mm | Max n_s: 8.43e+13 cm^-2
# Iter 130 | ΔV: 38.38mV | Max Temp: 325.1K | I_D: 2451.1 mA/mm | Max n_s: 8.27e+13 cm^-2
# Iter 140 | ΔV: 34.67mV | Max Temp: 327.1K | I_D: 2251.8 mA/mm | Max n_s: 8.08e+13 cm^-2
# Iter 150 | ΔV: 31.15mV | Max Temp: 329.1K | I_D: 2028.0 mA/mm | Max n_s: 7.87e+13 cm^-2
# Iter 160 | ΔV: 29.81mV | Max Temp: 331.1K | I_D: 1798.1 mA/mm | Max n_s: 7.65e+13 cm^-2
# Iter 170 | ΔV: 28.27mV | Max Temp: 333.1K | I_D: 1576.6 mA/mm | Max n_s: 7.43e+13 cm^-2
# Iter 180 | ΔV: 27.33mV | Max Temp: 335.1K | I_D: 1374.8 mA/mm | Max n_s: 7.21e+13 cm^-2
# Iter 190 | ΔV: 27.30mV | Max Temp: 337.1K | I_D: 1201.0 mA/mm | Max n_s: 7.00e+13 cm^-2
# Iter 200 | ΔV: 24.91mV | Max Temp: 338.9K | I_D: 1064.3 mA/mm | Max n_s: 6.79e+13 cm^-2
# Iter 210 | ΔV: 20.57mV | Max Temp: 340.3K | I_D: 976.3 mA/mm | Max n_s: 6.60e+13 cm^-2
# Iter 220 | ΔV: 15.48mV | Max Temp: 340.5K | I_D: 937.1 mA/mm | Max n_s: 6.41e+13 cm^-2
# Iter 230 | ΔV: 17.61mV | Max Temp: 339.7K | I_D: 932.9 mA/mm | Max n_s: 6.23e+13 cm^-2
# Iter 240 | ΔV: 19.45mV | Max Temp: 338.3K | I_D: 944.5 mA/mm | Max n_s: 6.06e+13 cm^-2
# Iter 250 | ΔV: 22.06mV | Max Temp: 336.9K | I_D: 970.7 mA/mm | Max n_s: 5.90e+13 cm^-2
# Iter 260 | ΔV: 25.92mV | Max Temp: 335.7K | I_D: 1025.0 mA/mm | Max n_s: 5.74e+13 cm^-2
# Iter 270 | ΔV: 39.90mV | Max Temp: 335.1K | I_D: 1096.4 mA/mm | Max n_s: 5.59e+13 cm^-2
# Iter 280 | ΔV: 55.92mV | Max Temp: 335.5K | I_D: 1137.6 mA/mm | Max n_s: 5.44e+13 cm^-2
# Iter 290 | ΔV: 72.24mV | Max Temp: 337.1K | I_D: 1124.8 mA/mm | Max n_s: 5.29e+13 cm^-2
# Iter 300 | ΔV: 83.13mV | Max Temp: 339.1K | I_D: 1120.3 mA/mm | Max n_s: 5.18e+13 cm^-2
#
# [!] Divergence detected at iter 301. Rolling back to stable moving average: 1115.88 mA/mm.
#
# ============================================================
#  STARTING SWEEP RUN (Vg = -1.0V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5569.65mV | Max Temp: 300.0K | I_D: 32.3 mA/mm | Max n_s: 1.03e+12 cm^-2
# Iter  10 | ΔV: 2268.36mV | Max Temp: 301.1K | I_D: 710.6 mA/mm | Max n_s: 1.86e+13 cm^-2
# Iter  20 | ΔV: 865.79mV | Max Temp: 303.1K | I_D: 1241.9 mA/mm | Max n_s: 3.58e+13 cm^-2
# Iter  30 | ΔV: 495.89mV | Max Temp: 305.1K | I_D: 1640.9 mA/mm | Max n_s: 5.06e+13 cm^-2
# Iter  40 | ΔV: 287.41mV | Max Temp: 307.1K | I_D: 1709.4 mA/mm | Max n_s: 6.22e+13 cm^-2
# Iter  50 | ΔV: 206.80mV | Max Temp: 309.1K | I_D: 1711.6 mA/mm | Max n_s: 7.08e+13 cm^-2
# Iter  60 | ΔV: 170.30mV | Max Temp: 311.1K | I_D: 1560.8 mA/mm | Max n_s: 7.70e+13 cm^-2
# Iter  70 | ΔV: 118.21mV | Max Temp: 313.1K | I_D: 1481.7 mA/mm | Max n_s: 8.11e+13 cm^-2
# Iter  80 | ΔV: 83.77mV | Max Temp: 315.1K | I_D: 1540.4 mA/mm | Max n_s: 8.37e+13 cm^-2
# Iter  90 | ΔV: 75.26mV | Max Temp: 317.1K | I_D: 1723.0 mA/mm | Max n_s: 8.50e+13 cm^-2
# Iter 100 | ΔV: 62.03mV | Max Temp: 319.1K | I_D: 2002.8 mA/mm | Max n_s: 8.52e+13 cm^-2
# Iter 110 | ΔV: 49.94mV | Max Temp: 321.1K | I_D: 2293.7 mA/mm | Max n_s: 8.45e+13 cm^-2
# Iter 120 | ΔV: 46.06mV | Max Temp: 323.1K | I_D: 2483.6 mA/mm | Max n_s: 8.33e+13 cm^-2
# Iter 130 | ΔV: 42.96mV | Max Temp: 325.1K | I_D: 2523.8 mA/mm | Max n_s: 8.16e+13 cm^-2
# Iter 140 | ΔV: 39.27mV | Max Temp: 327.1K | I_D: 2432.8 mA/mm | Max n_s: 7.96e+13 cm^-2
# Iter 150 | ΔV: 35.23mV | Max Temp: 329.1K | I_D: 2250.9 mA/mm | Max n_s: 7.74e+13 cm^-2
# Iter 160 | ΔV: 32.44mV | Max Temp: 331.1K | I_D: 2019.6 mA/mm | Max n_s: 7.52e+13 cm^-2
# Iter 170 | ΔV: 31.12mV | Max Temp: 333.1K | I_D: 1772.3 mA/mm | Max n_s: 7.29e+13 cm^-2
# Iter 180 | ΔV: 32.28mV | Max Temp: 335.1K | I_D: 1532.5 mA/mm | Max n_s: 7.06e+13 cm^-2
# Iter 190 | ΔV: 34.53mV | Max Temp: 337.1K | I_D: 1314.2 mA/mm | Max n_s: 6.84e+13 cm^-2
# Iter 200 | ΔV: 34.27mV | Max Temp: 339.1K | I_D: 1124.6 mA/mm | Max n_s: 6.63e+13 cm^-2
# Iter 210 | ΔV: 31.92mV | Max Temp: 340.6K | I_D: 968.5 mA/mm | Max n_s: 6.43e+13 cm^-2
# Iter 220 | ΔV: 27.85mV | Max Temp: 341.8K | I_D: 854.5 mA/mm | Max n_s: 6.25e+13 cm^-2
# Iter 230 | ΔV: 22.41mV | Max Temp: 341.3K | I_D: 788.3 mA/mm | Max n_s: 6.07e+13 cm^-2
# Iter 240 | ΔV: 16.90mV | Max Temp: 339.8K | I_D: 780.9 mA/mm | Max n_s: 5.91e+13 cm^-2
# Iter 250 | ΔV: 18.25mV | Max Temp: 337.8K | I_D: 840.2 mA/mm | Max n_s: 5.75e+13 cm^-2
# Iter 260 | ΔV: 19.74mV | Max Temp: 335.8K | I_D: 928.2 mA/mm | Max n_s: 5.61e+13 cm^-2
# Iter 270 | ΔV: 24.39mV | Max Temp: 333.8K | I_D: 956.6 mA/mm | Max n_s: 5.46e+13 cm^-2
# Iter 280 | ΔV: 29.20mV | Max Temp: 331.8K | I_D: 912.1 mA/mm | Max n_s: 5.32e+13 cm^-2
# Iter 290 | ΔV: 35.79mV | Max Temp: 329.9K | I_D: 862.1 mA/mm | Max n_s: 5.19e+13 cm^-2
# Iter 300 | ΔV: 46.42mV | Max Temp: 328.8K | I_D: 833.5 mA/mm | Max n_s: 5.10e+13 cm^-2
# Iter 310 | ΔV: 54.74mV | Max Temp: 328.6K | I_D: 825.2 mA/mm | Max n_s: 5.13e+13 cm^-2
#
# [!] Divergence detected at iter 314. Rolling back to stable moving average: 825.42 mA/mm.
#
# ============================================================
#  STARTING SWEEP RUN (Vg = -1.5V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5506.64mV | Max Temp: 300.0K | I_D: 30.1 mA/mm | Max n_s: 9.96e+11 cm^-2
# Iter  10 | ΔV: 2473.19mV | Max Temp: 301.0K | I_D: 670.4 mA/mm | Max n_s: 1.83e+13 cm^-2
# Iter  20 | ΔV: 865.87mV | Max Temp: 303.0K | I_D: 753.2 mA/mm | Max n_s: 3.52e+13 cm^-2
# Iter  30 | ΔV: 496.00mV | Max Temp: 305.0K | I_D: 898.7 mA/mm | Max n_s: 4.97e+13 cm^-2
# Iter  40 | ΔV: 287.40mV | Max Temp: 307.0K | I_D: 1141.5 mA/mm | Max n_s: 6.11e+13 cm^-2
# Iter  50 | ΔV: 192.37mV | Max Temp: 309.0K | I_D: 1339.8 mA/mm | Max n_s: 6.95e+13 cm^-2
# Iter  60 | ΔV: 160.65mV | Max Temp: 311.0K | I_D: 1382.7 mA/mm | Max n_s: 7.56e+13 cm^-2
# Iter  70 | ΔV: 143.04mV | Max Temp: 313.0K | I_D: 1340.2 mA/mm | Max n_s: 7.96e+13 cm^-2
# Iter  80 | ΔV: 120.32mV | Max Temp: 315.0K | I_D: 1207.6 mA/mm | Max n_s: 8.21e+13 cm^-2
# Iter  90 | ΔV: 93.75mV | Max Temp: 317.0K | I_D: 1205.8 mA/mm | Max n_s: 9.41e+13 cm^-2
# Iter 100 | ΔV: 90.18mV | Max Temp: 319.0K | I_D: 1325.6 mA/mm | Max n_s: 1.03e+14 cm^-2
# Iter 110 | ΔV: 77.27mV | Max Temp: 321.0K | I_D: 1542.9 mA/mm | Max n_s: 1.04e+14 cm^-2
# Iter 120 | ΔV: 61.43mV | Max Temp: 323.0K | I_D: 1799.6 mA/mm | Max n_s: 9.73e+13 cm^-2
# Iter 130 | ΔV: 51.34mV | Max Temp: 325.0K | I_D: 2007.9 mA/mm | Max n_s: 8.75e+13 cm^-2
# Iter 140 | ΔV: 47.21mV | Max Temp: 327.0K | I_D: 2106.9 mA/mm | Max n_s: 7.79e+13 cm^-2
# Iter 150 | ΔV: 43.62mV | Max Temp: 329.0K | I_D: 2094.6 mA/mm | Max n_s: 7.57e+13 cm^-2
# Iter 160 | ΔV: 39.41mV | Max Temp: 331.0K | I_D: 1998.1 mA/mm | Max n_s: 7.33e+13 cm^-2
# Iter 170 | ΔV: 35.07mV | Max Temp: 333.0K | I_D: 1837.8 mA/mm | Max n_s: 7.08e+13 cm^-2
# Iter 180 | ΔV: 39.88mV | Max Temp: 335.0K | I_D: 1638.9 mA/mm | Max n_s: 6.84e+13 cm^-2
# Iter 190 | ΔV: 45.97mV | Max Temp: 337.0K | I_D: 1428.5 mA/mm | Max n_s: 6.61e+13 cm^-2
# Iter 200 | ΔV: 48.23mV | Max Temp: 339.0K | I_D: 1225.2 mA/mm | Max n_s: 6.38e+13 cm^-2
# Iter 210 | ΔV: 47.48mV | Max Temp: 341.0K | I_D: 1039.3 mA/mm | Max n_s: 6.17e+13 cm^-2
# Iter 220 | ΔV: 44.62mV | Max Temp: 342.5K | I_D: 878.1 mA/mm | Max n_s: 5.98e+13 cm^-2
# Iter 230 | ΔV: 40.30mV | Max Temp: 343.5K | I_D: 748.3 mA/mm | Max n_s: 5.80e+13 cm^-2
# Iter 240 | ΔV: 35.20mV | Max Temp: 342.6K | I_D: 648.4 mA/mm | Max n_s: 5.63e+13 cm^-2
# Iter 250 | ΔV: 29.80mV | Max Temp: 340.7K | I_D: 574.4 mA/mm | Max n_s: 5.48e+13 cm^-2
# Iter 260 | ΔV: 24.32mV | Max Temp: 338.7K | I_D: 523.5 mA/mm | Max n_s: 5.33e+13 cm^-2
# Iter 270 | ΔV: 24.78mV | Max Temp: 336.7K | I_D: 494.0 mA/mm | Max n_s: 5.20e+13 cm^-2
# Iter 280 | ΔV: 27.03mV | Max Temp: 334.7K | I_D: 482.2 mA/mm | Max n_s: 5.07e+13 cm^-2
#
# [!] Divergence detected at iter 289. Rolling back to stable moving average: 481.29 mA/mm.
#
# ============================================================
#  STARTING SWEEP RUN (Vg = -2.0V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5443.63mV | Max Temp: 300.0K | I_D: 28.0 mA/mm | Max n_s: 9.65e+11 cm^-2
# Iter  10 | ΔV: 2701.68mV | Max Temp: 301.0K | I_D: 645.8 mA/mm | Max n_s: 1.81e+13 cm^-2
# Iter  20 | ΔV: 947.53mV | Max Temp: 303.0K | I_D: 651.4 mA/mm | Max n_s: 3.48e+13 cm^-2
# Iter  30 | ΔV: 567.32mV | Max Temp: 305.0K | I_D: 635.9 mA/mm | Max n_s: 4.93e+13 cm^-2
# Iter  40 | ΔV: 339.68mV | Max Temp: 307.0K | I_D: 575.8 mA/mm | Max n_s: 6.05e+13 cm^-2
# Iter  50 | ΔV: 203.38mV | Max Temp: 308.7K | I_D: 498.2 mA/mm | Max n_s: 6.89e+13 cm^-2
# Iter  60 | ΔV: 139.57mV | Max Temp: 309.8K | I_D: 529.7 mA/mm | Max n_s: 7.50e+13 cm^-2
# Iter  70 | ΔV: 148.03mV | Max Temp: 311.4K | I_D: 685.2 mA/mm | Max n_s: 7.91e+13 cm^-2
# Iter  80 | ΔV: 136.40mV | Max Temp: 313.4K | I_D: 901.1 mA/mm | Max n_s: 8.16e+13 cm^-2
# Iter  90 | ΔV: 113.76mV | Max Temp: 315.4K | I_D: 1081.6 mA/mm | Max n_s: 8.28e+13 cm^-2
# Iter 100 | ΔV: 107.36mV | Max Temp: 317.4K | I_D: 1063.8 mA/mm | Max n_s: 8.30e+13 cm^-2
# Iter 110 | ΔV: 100.80mV | Max Temp: 319.4K | I_D: 1026.4 mA/mm | Max n_s: 9.50e+13 cm^-2
# Iter 120 | ΔV: 94.52mV | Max Temp: 321.4K | I_D: 1117.5 mA/mm | Max n_s: 1.13e+14 cm^-2
# Iter 130 | ΔV: 85.58mV | Max Temp: 323.4K | I_D: 1263.5 mA/mm | Max n_s: 1.20e+14 cm^-2
# Iter 140 | ΔV: 70.17mV | Max Temp: 325.4K | I_D: 1406.9 mA/mm | Max n_s: 1.16e+14 cm^-2
# Iter 150 | ΔV: 56.96mV | Max Temp: 327.4K | I_D: 1525.1 mA/mm | Max n_s: 1.07e+14 cm^-2
# Iter 160 | ΔV: 49.31mV | Max Temp: 329.4K | I_D: 1598.5 mA/mm | Max n_s: 9.38e+13 cm^-2
# Iter 170 | ΔV: 44.64mV | Max Temp: 331.4K | I_D: 1613.9 mA/mm | Max n_s: 7.84e+13 cm^-2
# Iter 180 | ΔV: 47.66mV | Max Temp: 333.4K | I_D: 1562.1 mA/mm | Max n_s: 6.71e+13 cm^-2
# Iter 190 | ΔV: 62.62mV | Max Temp: 335.4K | I_D: 1439.9 mA/mm | Max n_s: 6.46e+13 cm^-2
# Iter 200 | ΔV: 70.71mV | Max Temp: 337.4K | I_D: 1271.9 mA/mm | Max n_s: 6.21e+13 cm^-2
# Iter 210 | ΔV: 71.41mV | Max Temp: 339.4K | I_D: 1093.9 mA/mm | Max n_s: 5.97e+13 cm^-2
# Iter 220 | ΔV: 67.24mV | Max Temp: 341.4K | I_D: 925.8 mA/mm | Max n_s: 5.75e+13 cm^-2
# Iter 230 | ΔV: 60.67mV | Max Temp: 343.4K | I_D: 776.1 mA/mm | Max n_s: 5.55e+13 cm^-2
# Iter 240 | ΔV: 53.19mV | Max Temp: 344.0K | I_D: 651.9 mA/mm | Max n_s: 5.36e+13 cm^-2
# Iter 250 | ΔV: 45.82mV | Max Temp: 342.9K | I_D: 551.4 mA/mm | Max n_s: 5.19e+13 cm^-2
# Iter 260 | ΔV: 39.15mV | Max Temp: 340.9K | I_D: 469.3 mA/mm | Max n_s: 5.04e+13 cm^-2
# Iter 270 | ΔV: 33.35mV | Max Temp: 338.9K | I_D: 402.9 mA/mm | Max n_s: 4.90e+13 cm^-2
# Iter 280 | ΔV: 28.35mV | Max Temp: 336.9K | I_D: 350.3 mA/mm | Max n_s: 4.77e+13 cm^-2
# Iter 290 | ΔV: 23.99mV | Max Temp: 334.9K | I_D: 309.6 mA/mm | Max n_s: 4.65e+13 cm^-2
# Iter 300 | ΔV: 25.07mV | Max Temp: 332.9K | I_D: 278.4 mA/mm | Max n_s: 4.53e+13 cm^-2
# Iter 310 | ΔV: 30.21mV | Max Temp: 330.9K | I_D: 254.2 mA/mm | Max n_s: 4.43e+13 cm^-2
# Iter 320 | ΔV: 35.90mV | Max Temp: 328.9K | I_D: 234.8 mA/mm | Max n_s: 4.33e+13 cm^-2
# Iter 330 | ΔV: 42.43mV | Max Temp: 326.9K | I_D: 218.2 mA/mm | Max n_s: 4.33e+13 cm^-2
# Iter 340 | ΔV: 49.98mV | Max Temp: 324.9K | I_D: 203.4 mA/mm | Max n_s: 4.34e+13 cm^-2
# Iter 350 | ΔV: 59.04mV | Max Temp: 322.9K | I_D: 189.5 mA/mm | Max n_s: 4.33e+13 cm^-2
# Iter 360 | ΔV: 67.19mV | Max Temp: 320.9K | I_D: 176.7 mA/mm | Max n_s: 4.30e+13 cm^-2
# Iter 370 | ΔV: 71.89mV | Max Temp: 318.9K | I_D: 164.9 mA/mm | Max n_s: 4.25e+13 cm^-2
# Iter 380 | ΔV: 72.15mV | Max Temp: 316.9K | I_D: 154.5 mA/mm | Max n_s: 4.18e+13 cm^-2
# Iter 390 | ΔV: 68.02mV | Max Temp: 314.9K | I_D: 145.6 mA/mm | Max n_s: 4.10e+13 cm^-2
# Iter 400 | ΔV: 60.41mV | Max Temp: 312.9K | I_D: 138.5 mA/mm | Max n_s: 4.00e+13 cm^-2
# Iter 410 | ΔV: 50.74mV | Max Temp: 311.1K | I_D: 133.6 mA/mm | Max n_s: 3.91e+13 cm^-2
# Iter 420 | ΔV: 40.44mV | Max Temp: 309.6K | I_D: 132.2 mA/mm | Max n_s: 3.83e+13 cm^-2
#
# [!] Divergence detected at iter 423. Rolling back to stable moving average: 132.17 mA/mm.
#
# ============================================================
#  STARTING SWEEP RUN (Vg = -2.5V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5380.62mV | Max Temp: 300.0K | I_D: 25.9 mA/mm | Max n_s: 9.34e+11 cm^-2
# Iter  10 | ΔV: 2884.18mV | Max Temp: 300.9K | I_D: 627.3 mA/mm | Max n_s: 1.79e+13 cm^-2
# Iter  20 | ΔV: 1126.77mV | Max Temp: 302.9K | I_D: 607.1 mA/mm | Max n_s: 3.45e+13 cm^-2
# Iter  30 | ΔV: 674.64mV | Max Temp: 304.9K | I_D: 555.8 mA/mm | Max n_s: 4.88e+13 cm^-2
# Iter  40 | ΔV: 403.93mV | Max Temp: 306.9K | I_D: 480.9 mA/mm | Max n_s: 6.00e+13 cm^-2
# Iter  50 | ΔV: 241.85mV | Max Temp: 308.4K | I_D: 379.3 mA/mm | Max n_s: 6.83e+13 cm^-2
# Iter  60 | ΔV: 144.80mV | Max Temp: 309.2K | I_D: 290.4 mA/mm | Max n_s: 7.44e+13 cm^-2
# Iter  70 | ΔV: 86.70mV | Max Temp: 309.5K | I_D: 225.0 mA/mm | Max n_s: 7.84e+13 cm^-2
# Iter  80 | ΔV: 59.72mV | Max Temp: 309.3K | I_D: 185.1 mA/mm | Max n_s: 8.09e+13 cm^-2
# Iter  90 | ΔV: 74.87mV | Max Temp: 308.8K | I_D: 175.5 mA/mm | Max n_s: 8.22e+13 cm^-2
# Iter 100 | ΔV: 104.95mV | Max Temp: 308.3K | I_D: 196.3 mA/mm | Max n_s: 8.24e+13 cm^-2
# Iter 110 | ΔV: 121.31mV | Max Temp: 308.8K | I_D: 282.8 mA/mm | Max n_s: 8.26e+13 cm^-2
# Iter 120 | ΔV: 129.48mV | Max Temp: 310.8K | I_D: 488.0 mA/mm | Max n_s: 8.26e+13 cm^-2
# Iter 130 | ΔV: 119.71mV | Max Temp: 312.8K | I_D: 738.4 mA/mm | Max n_s: 8.17e+13 cm^-2
# Iter 140 | ΔV: 102.17mV | Max Temp: 314.8K | I_D: 868.6 mA/mm | Max n_s: 8.03e+13 cm^-2
# Iter 150 | ΔV: 85.71mV | Max Temp: 316.8K | I_D: 939.9 mA/mm | Max n_s: 9.17e+13 cm^-2
# Iter 160 | ΔV: 80.44mV | Max Temp: 318.8K | I_D: 1021.4 mA/mm | Max n_s: 1.07e+14 cm^-2
# Iter 170 | ΔV: 69.19mV | Max Temp: 320.8K | I_D: 1082.9 mA/mm | Max n_s: 1.10e+14 cm^-2
# Iter 180 | ΔV: 55.38mV | Max Temp: 322.8K | I_D: 1118.4 mA/mm | Max n_s: 1.02e+14 cm^-2
# Iter 190 | ΔV: 68.90mV | Max Temp: 324.8K | I_D: 1110.9 mA/mm | Max n_s: 8.68e+13 cm^-2
# Iter 200 | ΔV: 101.03mV | Max Temp: 326.8K | I_D: 1049.4 mA/mm | Max n_s: 7.06e+13 cm^-2
# Iter 210 | ΔV: 113.37mV | Max Temp: 328.8K | I_D: 936.9 mA/mm | Max n_s: 5.83e+13 cm^-2
# Iter 220 | ΔV: 111.46mV | Max Temp: 330.8K | I_D: 798.7 mA/mm | Max n_s: 5.58e+13 cm^-2
# Iter 230 | ΔV: 102.03mV | Max Temp: 332.8K | I_D: 664.9 mA/mm | Max n_s: 5.34e+13 cm^-2
# Iter 240 | ΔV: 89.49mV | Max Temp: 334.8K | I_D: 548.2 mA/mm | Max n_s: 5.12e+13 cm^-2
# Iter 250 | ΔV: 76.44mV | Max Temp: 335.7K | I_D: 452.7 mA/mm | Max n_s: 4.92e+13 cm^-2
# Iter 260 | ΔV: 64.36mV | Max Temp: 335.0K | I_D: 376.3 mA/mm | Max n_s: 4.74e+13 cm^-2
# Iter 270 | ΔV: 54.03mV | Max Temp: 333.1K | I_D: 313.6 mA/mm | Max n_s: 4.57e+13 cm^-2
# Iter 280 | ΔV: 45.63mV | Max Temp: 331.1K | I_D: 261.5 mA/mm | Max n_s: 4.41e+13 cm^-2
# Iter 290 | ΔV: 39.03mV | Max Temp: 329.1K | I_D: 218.4 mA/mm | Max n_s: 4.28e+13 cm^-2
# Iter 300 | ΔV: 33.88mV | Max Temp: 327.1K | I_D: 183.1 mA/mm | Max n_s: 4.15e+13 cm^-2
# Iter 310 | ΔV: 29.82mV | Max Temp: 325.1K | I_D: 154.2 mA/mm | Max n_s: 4.04e+13 cm^-2
# Iter 320 | ΔV: 26.51mV | Max Temp: 323.1K | I_D: 130.7 mA/mm | Max n_s: 3.94e+13 cm^-2
# Iter 330 | ΔV: 27.52mV | Max Temp: 321.1K | I_D: 111.3 mA/mm | Max n_s: 3.85e+13 cm^-2
# Iter 340 | ΔV: 32.34mV | Max Temp: 319.1K | I_D: 95.3 mA/mm | Max n_s: 3.77e+13 cm^-2
# Iter 350 | ΔV: 38.22mV | Max Temp: 317.1K | I_D: 81.9 mA/mm | Max n_s: 3.75e+13 cm^-2
# Iter 360 | ΔV: 45.16mV | Max Temp: 315.1K | I_D: 70.4 mA/mm | Max n_s: 3.72e+13 cm^-2
# Iter 370 | ΔV: 53.05mV | Max Temp: 313.1K | I_D: 60.4 mA/mm | Max n_s: 3.69e+13 cm^-2
# Iter 380 | ΔV: 60.03mV | Max Temp: 311.2K | I_D: 51.8 mA/mm | Max n_s: 3.65e+13 cm^-2
# Iter 390 | ΔV: 63.88mV | Max Temp: 309.5K | I_D: 44.2 mA/mm | Max n_s: 3.61e+13 cm^-2
# Iter 400 | ΔV: 63.91mV | Max Temp: 308.0K | I_D: 37.6 mA/mm | Max n_s: 3.56e+13 cm^-2
# Iter 410 | ΔV: 60.26mV | Max Temp: 306.8K | I_D: 31.8 mA/mm | Max n_s: 3.51e+13 cm^-2
# Iter 420 | ΔV: 53.73mV | Max Temp: 305.8K | I_D: 26.8 mA/mm | Max n_s: 3.46e+13 cm^-2
# Iter 430 | ΔV: 45.51mV | Max Temp: 304.9K | I_D: 22.5 mA/mm | Max n_s: 3.41e+13 cm^-2
# Iter 440 | ΔV: 36.84mV | Max Temp: 304.1K | I_D: 18.8 mA/mm | Max n_s: 3.36e+13 cm^-2
# Iter 450 | ΔV: 28.67mV | Max Temp: 303.5K | I_D: 15.7 mA/mm | Max n_s: 3.33e+13 cm^-2
# Iter 460 | ΔV: 21.58mV | Max Temp: 303.0K | I_D: 13.1 mA/mm | Max n_s: 3.29e+13 cm^-2
# Iter 470 | ΔV: 17.45mV | Max Temp: 302.5K | I_D: 11.0 mA/mm | Max n_s: 3.26e+13 cm^-2
# Iter 480 | ΔV: 18.03mV | Max Temp: 302.2K | I_D: 9.2 mA/mm | Max n_s: 3.23e+13 cm^-2
# Iter 490 | ΔV: 18.30mV | Max Temp: 301.8K | I_D: 7.8 mA/mm | Max n_s: 3.20e+13 cm^-2
# Iter 500 | ΔV: 18.50mV | Max Temp: 301.6K | I_D: 6.7 mA/mm | Max n_s: 3.18e+13 cm^-2
# Iter 510 | ΔV: 18.44mV | Max Temp: 301.3K | I_D: 5.8 mA/mm | Max n_s: 3.17e+13 cm^-2
# Iter 520 | ΔV: 17.77mV | Max Temp: 301.1K | I_D: 5.2 mA/mm | Max n_s: 3.16e+13 cm^-2
# Iter 530 | ΔV: 17.11mV | Max Temp: 301.0K | I_D: 4.7 mA/mm | Max n_s: 3.15e+13 cm^-2
# Iter 540 | ΔV: 16.26mV | Max Temp: 300.8K | I_D: 4.4 mA/mm | Max n_s: 3.14e+13 cm^-2
# Iter 550 | ΔV: 14.60mV | Max Temp: 300.7K | I_D: 4.3 mA/mm | Max n_s: 3.14e+13 cm^-2
# Iter 560 | ΔV: 13.11mV | Max Temp: 300.6K | I_D: 4.2 mA/mm | Max n_s: 3.13e+13 cm^-2
#
# [!] Divergence detected at iter 567. Rolling back to stable moving average: 4.22 mA/mm.
#
# ============================================================
#  STARTING SWEEP RUN (Vg = -3.0V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5317.60mV | Max Temp: 300.0K | I_D: 24.0 mA/mm | Max n_s: 9.04e+11 cm^-2
# Iter  10 | ΔV: 2978.73mV | Max Temp: 300.9K | I_D: 611.8 mA/mm | Max n_s: 1.76e+13 cm^-2
# Iter  20 | ΔV: 1306.01mV | Max Temp: 302.9K | I_D: 579.3 mA/mm | Max n_s: 3.41e+13 cm^-2
# Iter  30 | ΔV: 781.96mV | Max Temp: 304.9K | I_D: 512.5 mA/mm | Max n_s: 4.83e+13 cm^-2
# Iter  40 | ΔV: 468.19mV | Max Temp: 306.8K | I_D: 434.9 mA/mm | Max n_s: 5.94e+13 cm^-2
# Iter  50 | ΔV: 280.32mV | Max Temp: 308.1K | I_D: 340.0 mA/mm | Max n_s: 6.77e+13 cm^-2
# Iter  60 | ΔV: 167.84mV | Max Temp: 308.9K | I_D: 258.4 mA/mm | Max n_s: 7.37e+13 cm^-2
# Iter  70 | ΔV: 100.49mV | Max Temp: 309.1K | I_D: 196.5 mA/mm | Max n_s: 7.77e+13 cm^-2
# Iter  80 | ΔV: 60.17mV | Max Temp: 308.8K | I_D: 150.9 mA/mm | Max n_s: 8.02e+13 cm^-2
# Iter  90 | ΔV: 42.67mV | Max Temp: 308.2K | I_D: 117.3 mA/mm | Max n_s: 8.15e+13 cm^-2
# Iter 100 | ΔV: 41.76mV | Max Temp: 307.5K | I_D: 92.2 mA/mm | Max n_s: 8.17e+13 cm^-2
# Iter 110 | ΔV: 40.32mV | Max Temp: 306.8K | I_D: 73.2 mA/mm | Max n_s: 8.18e+13 cm^-2
# Iter 120 | ΔV: 38.43mV | Max Temp: 306.0K | I_D: 58.7 mA/mm | Max n_s: 8.17e+13 cm^-2
# Iter 130 | ΔV: 41.65mV | Max Temp: 305.3K | I_D: 47.6 mA/mm | Max n_s: 8.10e+13 cm^-2
# Iter 140 | ΔV: 46.01mV | Max Temp: 304.6K | I_D: 39.1 mA/mm | Max n_s: 7.96e+13 cm^-2
# Iter 150 | ΔV: 54.29mV | Max Temp: 304.0K | I_D: 32.7 mA/mm | Max n_s: 7.78e+13 cm^-2
# Iter 160 | ΔV: 72.84mV | Max Temp: 303.4K | I_D: 28.2 mA/mm | Max n_s: 7.56e+13 cm^-2
# Iter 170 | ΔV: 103.91mV | Max Temp: 303.0K | I_D: 28.3 mA/mm | Max n_s: 7.32e+13 cm^-2
# Iter 180 | ΔV: 123.28mV | Max Temp: 303.8K | I_D: 95.1 mA/mm | Max n_s: 7.06e+13 cm^-2
# Iter 190 | ΔV: 126.48mV | Max Temp: 305.8K | I_D: 302.1 mA/mm | Max n_s: 6.78e+13 cm^-2
# Iter 200 | ΔV: 90.06mV | Max Temp: 307.8K | I_D: 492.2 mA/mm | Max n_s: 6.50e+13 cm^-2
# Iter 210 | ΔV: 40.38mV | Max Temp: 309.8K | I_D: 458.5 mA/mm | Max n_s: 6.20e+13 cm^-2
# Iter 220 | ΔV: 94.52mV | Max Temp: 311.8K | I_D: 343.1 mA/mm | Max n_s: 5.90e+13 cm^-2
# Iter 230 | ΔV: 209.29mV | Max Temp: 313.8K | I_D: 234.2 mA/mm | Max n_s: 5.60e+13 cm^-2
# Iter 240 | ΔV: 238.22mV | Max Temp: 315.8K | I_D: 154.0 mA/mm | Max n_s: 5.32e+13 cm^-2
# Iter 250 | ΔV: 214.25mV | Max Temp: 317.5K | I_D: 101.9 mA/mm | Max n_s: 5.05e+13 cm^-2
# Iter 260 | ΔV: 179.09mV | Max Temp: 317.8K | I_D: 69.2 mA/mm | Max n_s: 4.80e+13 cm^-2
# Iter 270 | ΔV: 145.68mV | Max Temp: 316.8K | I_D: 48.4 mA/mm | Max n_s: 4.57e+13 cm^-2
# Iter 280 | ΔV: 116.64mV | Max Temp: 315.1K | I_D: 34.6 mA/mm | Max n_s: 4.35e+13 cm^-2
# Iter 290 | ΔV: 92.70mV | Max Temp: 313.2K | I_D: 25.3 mA/mm | Max n_s: 4.16e+13 cm^-2
# Iter 300 | ΔV: 73.78mV | Max Temp: 311.4K | I_D: 18.8 mA/mm | Max n_s: 3.98e+13 cm^-2
# Iter 310 | ΔV: 59.21mV | Max Temp: 309.7K | I_D: 14.2 mA/mm | Max n_s: 3.82e+13 cm^-2
# Iter 320 | ΔV: 48.16mV | Max Temp: 308.2K | I_D: 10.9 mA/mm | Max n_s: 3.68e+13 cm^-2
# Iter 330 | ΔV: 39.86mV | Max Temp: 306.9K | I_D: 8.4 mA/mm | Max n_s: 3.56e+13 cm^-2
# Iter 340 | ΔV: 33.61mV | Max Temp: 305.8K | I_D: 6.5 mA/mm | Max n_s: 3.45e+13 cm^-2
# Iter 350 | ΔV: 28.90mV | Max Temp: 304.8K | I_D: 5.1 mA/mm | Max n_s: 3.36e+13 cm^-2
# Iter 360 | ΔV: 28.26mV | Max Temp: 304.0K | I_D: 4.1 mA/mm | Max n_s: 3.29e+13 cm^-2
# Iter 370 | ΔV: 34.26mV | Max Temp: 303.3K | I_D: 3.2 mA/mm | Max n_s: 3.23e+13 cm^-2
# Iter 380 | ΔV: 39.61mV | Max Temp: 302.7K | I_D: 2.6 mA/mm | Max n_s: 3.18e+13 cm^-2
# Iter 390 | ΔV: 42.81mV | Max Temp: 302.3K | I_D: 2.1 mA/mm | Max n_s: 3.15e+13 cm^-2
# Iter 400 | ΔV: 43.28mV | Max Temp: 301.9K | I_D: 1.7 mA/mm | Max n_s: 3.12e+13 cm^-2
# Iter 410 | ΔV: 41.17mV | Max Temp: 301.5K | I_D: 1.4 mA/mm | Max n_s: 3.11e+13 cm^-2
# Iter 420 | ΔV: 37.04mV | Max Temp: 301.3K | I_D: 1.2 mA/mm | Max n_s: 3.10e+13 cm^-2
# Iter 430 | ΔV: 31.69mV | Max Temp: 301.1K | I_D: 1.0 mA/mm | Max n_s: 3.09e+13 cm^-2
# Iter 440 | ΔV: 25.93mV | Max Temp: 300.9K | I_D: 0.9 mA/mm | Max n_s: 3.09e+13 cm^-2
# Iter 450 | ΔV: 20.42mV | Max Temp: 300.7K | I_D: 0.8 mA/mm | Max n_s: 3.09e+13 cm^-2
# Iter 460 | ΔV: 15.55mV | Max Temp: 300.6K | I_D: 0.7 mA/mm | Max n_s: 3.09e+13 cm^-2
# Iter 470 | ΔV: 11.52mV | Max Temp: 300.5K | I_D: 0.6 mA/mm | Max n_s: 3.10e+13 cm^-2
# Iter 480 | ΔV: 8.34mV | Max Temp: 300.4K | I_D: 0.5 mA/mm | Max n_s: 3.10e+13 cm^-2
# Iter 490 | ΔV: 5.92mV | Max Temp: 300.3K | I_D: 0.5 mA/mm | Max n_s: 3.11e+13 cm^-2
# Iter 500 | ΔV: 4.13mV | Max Temp: 300.3K | I_D: 0.4 mA/mm | Max n_s: 3.11e+13 cm^-2
# Iter 510 | ΔV: 2.82mV | Max Temp: 300.2K | I_D: 0.4 mA/mm | Max n_s: 3.12e+13 cm^-2
# Iter 520 | ΔV: 1.89mV | Max Temp: 300.2K | I_D: 0.4 mA/mm | Max n_s: 3.12e+13 cm^-2
# Iter 530 | ΔV: 1.25mV | Max Temp: 300.2K | I_D: 0.4 mA/mm | Max n_s: 3.12e+13 cm^-2
# Iter 540 | ΔV: 1.18mV | Max Temp: 300.1K | I_D: 0.4 mA/mm | Max n_s: 3.12e+13 cm^-2
# Iter 550 | ΔV: 1.21mV | Max Temp: 300.1K | I_D: 0.4 mA/mm | Max n_s: 3.13e+13 cm^-2
#
# [!] Divergence detected at iter 550. Rolling back to stable moving average: 0.35 mA/mm.
#
# ============================================================
#  STARTING SWEEP RUN (Vg = -3.5V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5254.59mV | Max Temp: 300.0K | I_D: 22.2 mA/mm | Max n_s: 8.73e+11 cm^-2
# Iter  10 | ΔV: 3008.51mV | Max Temp: 300.9K | I_D: 597.2 mA/mm | Max n_s: 1.74e+13 cm^-2
# Iter  20 | ΔV: 1485.26mV | Max Temp: 302.8K | I_D: 559.5 mA/mm | Max n_s: 3.37e+13 cm^-2
# Iter  30 | ΔV: 889.28mV | Max Temp: 304.8K | I_D: 484.8 mA/mm | Max n_s: 4.78e+13 cm^-2
# Iter  40 | ΔV: 532.44mV | Max Temp: 306.6K | I_D: 406.7 mA/mm | Max n_s: 5.88e+13 cm^-2
# Iter  50 | ΔV: 318.79mV | Max Temp: 307.8K | I_D: 316.2 mA/mm | Max n_s: 6.70e+13 cm^-2
# Iter  60 | ΔV: 190.87mV | Max Temp: 308.6K | I_D: 240.0 mA/mm | Max n_s: 7.30e+13 cm^-2
# Iter  70 | ΔV: 114.28mV | Max Temp: 308.7K | I_D: 182.3 mA/mm | Max n_s: 7.70e+13 cm^-2
# Iter  80 | ΔV: 68.43mV | Max Temp: 308.5K | I_D: 139.9 mA/mm | Max n_s: 7.95e+13 cm^-2
# Iter  90 | ΔV: 40.97mV | Max Temp: 307.9K | I_D: 108.6 mA/mm | Max n_s: 8.07e+13 cm^-2
# Iter 100 | ΔV: 37.91mV | Max Temp: 307.2K | I_D: 85.3 mA/mm | Max n_s: 8.09e+13 cm^-2
# Iter 110 | ΔV: 36.96mV | Max Temp: 306.5K | I_D: 67.6 mA/mm | Max n_s: 8.10e+13 cm^-2
# Iter 120 | ΔV: 35.63mV | Max Temp: 305.7K | I_D: 54.0 mA/mm | Max n_s: 8.09e+13 cm^-2
# Iter 130 | ΔV: 34.08mV | Max Temp: 305.0K | I_D: 43.5 mA/mm | Max n_s: 8.01e+13 cm^-2
# Iter 140 | ΔV: 32.57mV | Max Temp: 304.4K | I_D: 35.2 mA/mm | Max n_s: 7.88e+13 cm^-2
# Iter 150 | ΔV: 31.59mV | Max Temp: 303.8K | I_D: 28.6 mA/mm | Max n_s: 7.70e+13 cm^-2
# Iter 160 | ΔV: 30.77mV | Max Temp: 303.2K | I_D: 23.2 mA/mm | Max n_s: 7.48e+13 cm^-2
# Iter 170 | ΔV: 30.04mV | Max Temp: 302.8K | I_D: 18.9 mA/mm | Max n_s: 7.24e+13 cm^-2
# Iter 180 | ΔV: 29.35mV | Max Temp: 302.4K | I_D: 15.4 mA/mm | Max n_s: 6.98e+13 cm^-2
# Iter 190 | ΔV: 28.63mV | Max Temp: 302.0K | I_D: 12.4 mA/mm | Max n_s: 6.71e+13 cm^-2
# Iter 200 | ΔV: 27.88mV | Max Temp: 301.7K | I_D: 10.0 mA/mm | Max n_s: 6.43e+13 cm^-2
# Iter 210 | ΔV: 27.05mV | Max Temp: 301.4K | I_D: 8.0 mA/mm | Max n_s: 6.14e+13 cm^-2
# Iter 220 | ΔV: 26.16mV | Max Temp: 301.2K | I_D: 6.4 mA/mm | Max n_s: 5.86e+13 cm^-2
# Iter 230 | ΔV: 25.50mV | Max Temp: 301.0K | I_D: 5.1 mA/mm | Max n_s: 5.57e+13 cm^-2
# Iter 240 | ΔV: 26.11mV | Max Temp: 300.8K | I_D: 4.0 mA/mm | Max n_s: 5.31e+13 cm^-2
# Iter 250 | ΔV: 26.64mV | Max Temp: 300.7K | I_D: 3.2 mA/mm | Max n_s: 5.05e+13 cm^-2
# Iter 260 | ΔV: 27.65mV | Max Temp: 300.6K | I_D: 2.5 mA/mm | Max n_s: 4.81e+13 cm^-2
# Iter 270 | ΔV: 29.99mV | Max Temp: 300.5K | I_D: 1.9 mA/mm | Max n_s: 4.58e+13 cm^-2
# Iter 280 | ΔV: 31.50mV | Max Temp: 300.4K | I_D: 1.5 mA/mm | Max n_s: 4.36e+13 cm^-2
# Iter 290 | ΔV: 36.47mV | Max Temp: 300.3K | I_D: 1.2 mA/mm | Max n_s: 4.16e+13 cm^-2
# Iter 300 | ΔV: 46.95mV | Max Temp: 300.3K | I_D: 1.0 mA/mm | Max n_s: 3.97e+13 cm^-2
# Iter 310 | ΔV: 75.78mV | Max Temp: 300.2K | I_D: 0.9 mA/mm | Max n_s: 3.81e+13 cm^-2
#
# [!] Divergence detected at iter 312. Rolling back to stable moving average: 0.89 mA/mm.
#
# ============================================================
#  STARTING SWEEP RUN (Vg = -4.0V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5191.58mV | Max Temp: 300.0K | I_D: 20.5 mA/mm | Max n_s: 8.43e+11 cm^-2
# Iter  10 | ΔV: 3004.49mV | Max Temp: 300.8K | I_D: 581.8 mA/mm | Max n_s: 1.71e+13 cm^-2
# Iter  20 | ΔV: 1664.50mV | Max Temp: 302.7K | I_D: 544.8 mA/mm | Max n_s: 3.33e+13 cm^-2
# Iter  30 | ΔV: 996.60mV | Max Temp: 304.7K | I_D: 465.8 mA/mm | Max n_s: 4.73e+13 cm^-2
# Iter  40 | ΔV: 596.70mV | Max Temp: 306.4K | I_D: 387.8 mA/mm | Max n_s: 5.82e+13 cm^-2
# Iter  50 | ΔV: 357.27mV | Max Temp: 307.6K | I_D: 300.0 mA/mm | Max n_s: 6.64e+13 cm^-2
# Iter  60 | ΔV: 213.91mV | Max Temp: 308.4K | I_D: 227.2 mA/mm | Max n_s: 7.23e+13 cm^-2
# Iter  70 | ΔV: 128.07mV | Max Temp: 308.5K | I_D: 172.5 mA/mm | Max n_s: 7.63e+13 cm^-2
# Iter  80 | ΔV: 76.68mV | Max Temp: 308.2K | I_D: 132.4 mA/mm | Max n_s: 7.88e+13 cm^-2
# Iter  90 | ΔV: 45.91mV | Max Temp: 307.6K | I_D: 102.8 mA/mm | Max n_s: 8.00e+13 cm^-2
# Iter 100 | ΔV: 35.93mV | Max Temp: 307.0K | I_D: 80.7 mA/mm | Max n_s: 8.02e+13 cm^-2
# Iter 110 | ΔV: 34.95mV | Max Temp: 306.2K | I_D: 64.0 mA/mm | Max n_s: 8.02e+13 cm^-2
# Iter 120 | ΔV: 33.69mV | Max Temp: 305.5K | I_D: 51.2 mA/mm | Max n_s: 8.00e+13 cm^-2
# Iter 130 | ΔV: 32.53mV | Max Temp: 304.8K | I_D: 41.2 mA/mm | Max n_s: 7.92e+13 cm^-2
# Iter 140 | ΔV: 31.48mV | Max Temp: 304.2K | I_D: 33.3 mA/mm | Max n_s: 7.79e+13 cm^-2
# Iter 150 | ΔV: 30.65mV | Max Temp: 303.6K | I_D: 27.0 mA/mm | Max n_s: 7.61e+13 cm^-2
# Iter 160 | ΔV: 29.96mV | Max Temp: 303.1K | I_D: 22.0 mA/mm | Max n_s: 7.40e+13 cm^-2
# Iter 170 | ΔV: 29.29mV | Max Temp: 302.7K | I_D: 17.9 mA/mm | Max n_s: 7.16e+13 cm^-2
# Iter 180 | ΔV: 28.60mV | Max Temp: 302.3K | I_D: 14.5 mA/mm | Max n_s: 6.90e+13 cm^-2
# Iter 190 | ΔV: 27.87mV | Max Temp: 301.9K | I_D: 11.8 mA/mm | Max n_s: 6.63e+13 cm^-2
# Iter 200 | ΔV: 27.08mV | Max Temp: 301.6K | I_D: 9.5 mA/mm | Max n_s: 6.35e+13 cm^-2
# Iter 210 | ΔV: 26.20mV | Max Temp: 301.4K | I_D: 7.6 mA/mm | Max n_s: 6.06e+13 cm^-2
# Iter 220 | ΔV: 25.28mV | Max Temp: 301.1K | I_D: 6.1 mA/mm | Max n_s: 5.78e+13 cm^-2
# Iter 230 | ΔV: 24.25mV | Max Temp: 300.9K | I_D: 4.9 mA/mm | Max n_s: 5.51e+13 cm^-2
# Iter 240 | ΔV: 23.10mV | Max Temp: 300.8K | I_D: 3.8 mA/mm | Max n_s: 5.25e+13 cm^-2
# Iter 250 | ΔV: 21.83mV | Max Temp: 300.7K | I_D: 3.0 mA/mm | Max n_s: 4.99e+13 cm^-2
# Iter 260 | ΔV: 20.47mV | Max Temp: 300.5K | I_D: 2.4 mA/mm | Max n_s: 4.75e+13 cm^-2
# Iter 270 | ΔV: 19.03mV | Max Temp: 300.5K | I_D: 1.9 mA/mm | Max n_s: 4.52e+13 cm^-2
# Iter 280 | ΔV: 17.49mV | Max Temp: 300.4K | I_D: 1.5 mA/mm | Max n_s: 4.31e+13 cm^-2
# Iter 290 | ΔV: 15.84mV | Max Temp: 300.3K | I_D: 1.1 mA/mm | Max n_s: 4.11e+13 cm^-2
# Iter 300 | ΔV: 14.27mV | Max Temp: 300.3K | I_D: 0.9 mA/mm | Max n_s: 3.93e+13 cm^-2
# Iter 310 | ΔV: 12.71mV | Max Temp: 300.2K | I_D: 0.7 mA/mm | Max n_s: 3.77e+13 cm^-2
# Iter 320 | ΔV: 11.31mV | Max Temp: 300.2K | I_D: 0.5 mA/mm | Max n_s: 3.63e+13 cm^-2
# Iter 330 | ΔV: 9.91mV | Max Temp: 300.1K | I_D: 0.4 mA/mm | Max n_s: 3.51e+13 cm^-2
# Iter 340 | ΔV: 8.66mV | Max Temp: 300.1K | I_D: 0.3 mA/mm | Max n_s: 3.40e+13 cm^-2
# Iter 350 | ΔV: 7.44mV | Max Temp: 300.1K | I_D: 0.3 mA/mm | Max n_s: 3.31e+13 cm^-2
# Iter 360 | ΔV: 6.90mV | Max Temp: 300.1K | I_D: 0.2 mA/mm | Max n_s: 3.24e+13 cm^-2
# Iter 370 | ΔV: 7.28mV | Max Temp: 300.1K | I_D: 0.2 mA/mm | Max n_s: 3.18e+13 cm^-2
# Iter 380 | ΔV: 7.31mV | Max Temp: 300.1K | I_D: 0.1 mA/mm | Max n_s: 3.13e+13 cm^-2
# Iter 390 | ΔV: 7.07mV | Max Temp: 300.0K | I_D: 0.1 mA/mm | Max n_s: 3.10e+13 cm^-2
# Iter 400 | ΔV: 6.54mV | Max Temp: 300.0K | I_D: 0.1 mA/mm | Max n_s: 3.08e+13 cm^-2
# Iter 410 | ΔV: 5.81mV | Max Temp: 300.0K | I_D: 0.1 mA/mm | Max n_s: 3.07e+13 cm^-2
# Iter 420 | ΔV: 4.97mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.06e+13 cm^-2
# Iter 430 | ΔV: 4.14mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.05e+13 cm^-2
# Iter 440 | ΔV: 3.41mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.05e+13 cm^-2
# Iter 450 | ΔV: 2.81mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.05e+13 cm^-2
# Iter 460 | ΔV: 2.58mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.05e+13 cm^-2
# Iter 470 | ΔV: 2.53mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.06e+13 cm^-2
# Iter 480 | ΔV: 2.39mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.06e+13 cm^-2
# Iter 490 | ΔV: 2.42mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.07e+13 cm^-2
# Iter 500 | ΔV: 2.77mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.07e+13 cm^-2
# Iter 510 | ΔV: 3.08mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.07e+13 cm^-2
# Iter 520 | ΔV: 3.23mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.08e+13 cm^-2
# Iter 530 | ΔV: 3.20mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.08e+13 cm^-2
# Iter 540 | ΔV: 3.04mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.09e+13 cm^-2
# Iter 550 | ΔV: 2.77mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.09e+13 cm^-2
# Iter 560 | ΔV: 2.57mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.09e+13 cm^-2
# Iter 570 | ΔV: 2.80mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.09e+13 cm^-2
#
# [+] Converged successfully at iter 573 (ΔI_D < 0.0001 mA/mm).
#
# ============================================================
#  STARTING SWEEP RUN (Vg = -4.5V, Vds = 2.0V) - RF Simulation
# ============================================================
# Iter   0 | ΔV: 5143.14mV | Max Temp: 300.0K | I_D: 18.9 mA/mm | Max n_s: 8.13e+11 cm^-2
# Iter  10 | ΔV: 3079.39mV | Max Temp: 300.8K | I_D: 564.7 mA/mm | Max n_s: 1.69e+13 cm^-2
# Iter  20 | ΔV: 1843.74mV | Max Temp: 302.7K | I_D: 533.7 mA/mm | Max n_s: 3.29e+13 cm^-2
# Iter  30 | ΔV: 1103.92mV | Max Temp: 304.6K | I_D: 452.1 mA/mm | Max n_s: 4.68e+13 cm^-2
# Iter  40 | ΔV: 660.96mV | Max Temp: 306.2K | I_D: 374.5 mA/mm | Max n_s: 5.77e+13 cm^-2
# Iter  50 | ΔV: 395.74mV | Max Temp: 307.5K | I_D: 288.5 mA/mm | Max n_s: 6.58e+13 cm^-2
# Iter  60 | ΔV: 236.94mV | Max Temp: 308.1K | I_D: 217.8 mA/mm | Max n_s: 7.16e+13 cm^-2
# Iter  70 | ΔV: 141.87mV | Max Temp: 308.2K | I_D: 165.2 mA/mm | Max n_s: 7.56e+13 cm^-2
# Iter  80 | ΔV: 84.94mV | Max Temp: 307.9K | I_D: 126.8 mA/mm | Max n_s: 7.81e+13 cm^-2
# Iter  90 | ΔV: 50.86mV | Max Temp: 307.4K | I_D: 98.4 mA/mm | Max n_s: 7.93e+13 cm^-2
# Iter 100 | ΔV: 34.27mV | Max Temp: 306.7K | I_D: 77.3 mA/mm | Max n_s: 7.95e+13 cm^-2
# Iter 110 | ΔV: 33.48mV | Max Temp: 306.1K | I_D: 61.3 mA/mm | Max n_s: 7.94e+13 cm^-2
# Iter 120 | ΔV: 32.61mV | Max Temp: 305.4K | I_D: 49.0 mA/mm | Max n_s: 7.92e+13 cm^-2
# Iter 130 | ΔV: 31.58mV | Max Temp: 304.7K | I_D: 39.4 mA/mm | Max n_s: 7.83e+13 cm^-2
# Iter 140 | ΔV: 30.71mV | Max Temp: 304.1K | I_D: 31.9 mA/mm | Max n_s: 7.70e+13 cm^-2
# Iter 150 | ΔV: 30.00mV | Max Temp: 303.5K | I_D: 25.9 mA/mm | Max n_s: 7.52e+13 cm^-2
# Iter 160 | ΔV: 29.34mV | Max Temp: 303.0K | I_D: 21.0 mA/mm | Max n_s: 7.31e+13 cm^-2
# Iter 170 | ΔV: 28.68mV | Max Temp: 302.6K | I_D: 17.1 mA/mm | Max n_s: 7.07e+13 cm^-2
# Iter 180 | ΔV: 27.97mV | Max Temp: 302.2K | I_D: 13.9 mA/mm | Max n_s: 6.81e+13 cm^-2
# Iter 190 | ΔV: 27.24mV | Max Temp: 301.8K | I_D: 11.3 mA/mm | Max n_s: 6.54e+13 cm^-2
# Iter 200 | ΔV: 26.44mV | Max Temp: 301.6K | I_D: 9.1 mA/mm | Max n_s: 6.26e+13 cm^-2
# Iter 210 | ΔV: 25.55mV | Max Temp: 301.3K | I_D: 7.3 mA/mm | Max n_s: 5.98e+13 cm^-2
# Iter 220 | ΔV: 24.57mV | Max Temp: 301.1K | I_D: 5.9 mA/mm | Max n_s: 5.71e+13 cm^-2
# Iter 230 | ΔV: 23.49mV | Max Temp: 300.9K | I_D: 4.7 mA/mm | Max n_s: 5.44e+13 cm^-2
# Iter 240 | ΔV: 22.30mV | Max Temp: 300.8K | I_D: 3.7 mA/mm | Max n_s: 5.18e+13 cm^-2
# Iter 250 | ΔV: 21.01mV | Max Temp: 300.6K | I_D: 3.0 mA/mm | Max n_s: 4.93e+13 cm^-2
# Iter 260 | ΔV: 19.62mV | Max Temp: 300.5K | I_D: 2.3 mA/mm | Max n_s: 4.69e+13 cm^-2
# Iter 270 | ΔV: 18.14mV | Max Temp: 300.4K | I_D: 1.8 mA/mm | Max n_s: 4.47e+13 cm^-2
# Iter 280 | ΔV: 16.68mV | Max Temp: 300.4K | I_D: 1.4 mA/mm | Max n_s: 4.26e+13 cm^-2
# Iter 290 | ΔV: 15.16mV | Max Temp: 300.3K | I_D: 1.1 mA/mm | Max n_s: 4.06e+13 cm^-2
# Iter 300 | ΔV: 13.67mV | Max Temp: 300.2K | I_D: 0.9 mA/mm | Max n_s: 3.88e+13 cm^-2
# Iter 310 | ΔV: 12.26mV | Max Temp: 300.2K | I_D: 0.7 mA/mm | Max n_s: 3.73e+13 cm^-2
# Iter 320 | ΔV: 10.86mV | Max Temp: 300.2K | I_D: 0.5 mA/mm | Max n_s: 3.59e+13 cm^-2
# Iter 330 | ΔV: 9.59mV | Max Temp: 300.1K | I_D: 0.4 mA/mm | Max n_s: 3.47e+13 cm^-2
# Iter 340 | ΔV: 8.34mV | Max Temp: 300.1K | I_D: 0.3 mA/mm | Max n_s: 3.37e+13 cm^-2
# Iter 350 | ΔV: 7.15mV | Max Temp: 300.1K | I_D: 0.3 mA/mm | Max n_s: 3.28e+13 cm^-2
# Iter 360 | ΔV: 6.10mV | Max Temp: 300.1K | I_D: 0.2 mA/mm | Max n_s: 3.21e+13 cm^-2
# Iter 370 | ΔV: 6.32mV | Max Temp: 300.1K | I_D: 0.2 mA/mm | Max n_s: 3.16e+13 cm^-2
# Iter 380 | ΔV: 6.30mV | Max Temp: 300.1K | I_D: 0.1 mA/mm | Max n_s: 3.12e+13 cm^-2
# Iter 390 | ΔV: 6.10mV | Max Temp: 300.0K | I_D: 0.1 mA/mm | Max n_s: 3.09e+13 cm^-2
# Iter 400 | ΔV: 5.69mV | Max Temp: 300.0K | I_D: 0.1 mA/mm | Max n_s: 3.07e+13 cm^-2
# Iter 410 | ΔV: 5.11mV | Max Temp: 300.0K | I_D: 0.1 mA/mm | Max n_s: 3.05e+13 cm^-2
# Iter 420 | ΔV: 4.44mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.05e+13 cm^-2
# Iter 430 | ΔV: 3.75mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.04e+13 cm^-2
# Iter 440 | ΔV: 3.10mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.04e+13 cm^-2
# Iter 450 | ΔV: 2.54mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.04e+13 cm^-2
# Iter 460 | ΔV: 2.09mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.04e+13 cm^-2
# Iter 470 | ΔV: 1.75mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.05e+13 cm^-2
# Iter 480 | ΔV: 1.47mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.05e+13 cm^-2
# Iter 490 | ΔV: 1.22mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.05e+13 cm^-2
# Iter 500 | ΔV: 1.05mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.06e+13 cm^-2
# Iter 510 | ΔV: 0.93mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.06e+13 cm^-2
# Iter 520 | ΔV: 0.80mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.07e+13 cm^-2
# Iter 530 | ΔV: 0.75mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.07e+13 cm^-2
# Iter 540 | ΔV: 0.68mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.07e+13 cm^-2
# Iter 550 | ΔV: 0.60mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.08e+13 cm^-2
# Iter 560 | ΔV: 0.53mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.08e+13 cm^-2
# Iter 570 | ΔV: 0.45mV | Max Temp: 300.0K | I_D: 0.0 mA/mm | Max n_s: 3.08e+13 cm^-2
#
# [+] Converged successfully at iter 573 (ΔI_D < 0.0001 mA/mm).
